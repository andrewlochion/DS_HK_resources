# %% [markdown]
# ## Exploring Rossmann Drug Store Sales Data

# %%
import pandas as pd

data = pd.read_csv('../../assets/dataset/rossmann.csv', skipinitialspace=True, low_memory=False)

# %%
data
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# 5            6          5  2015-07-31   5651        589     1      1
# 6            7          5  2015-07-31  15344       1414     1      1
# 7            8          5  2015-07-31   8492        833     1      1
# 8            9          5  2015-07-31   8565        687     1      1
# 9           10          5  2015-07-31   7185        681     1      1
# 10          11          5  2015-07-31  10457       1236     1      1
# 11          12          5  2015-07-31   8959        962     1      1
# 12          13          5  2015-07-31   8821        568     1      1
# ...

# %% [markdown]
# Because we are most interested in the `Date` column that contains the date of sales for each store, we will make sure to process that as a `DateTime` type, and make that the index of our dataframe.

# %%
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)

data['Year'] = data.index.year
data['Month'] = data.index.month

# %%
data
# Out:
#             Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# Date
# 2015-07-31      1          5   5263        555     1      1            0
# 2015-07-31      2          5   6064        625     1      1            0
# 2015-07-31      3          5   8314        821     1      1            0
# 2015-07-31      4          5  13995       1498     1      1            0
# 2015-07-31      5          5   4822        559     1      1            0
# 2015-07-31      6          5   5651        589     1      1            0
# 2015-07-31      7          5  15344       1414     1      1            0
# 2015-07-31      8          5   8492        833     1      1            0
# 2015-07-31      9          5   8565        687     1      1            0
# 2015-07-31     10          5   7185        681     1      1            0
# 2015-07-31     11          5  10457       1236     1      1            0
# 2015-07-31     12          5   8959        962     1      1            0
# ...

# %%
store1_data = data[data.Store == 1]

# %% [markdown]
# ### Data Exploration and MINEing

# %% [markdown]
# To compare sales on holidays, we can compare the sales using box-plots, which allows us to compare the distribution of sales on holidays against all other days.  On state holidays, the store is closed (and as a nice sanity check there are 0 sales), and on school holidays the sales are relatively similar.

# %%
import seaborn as sb
# %matplotlib inline

sb.factorplot(
    x='SchoolHoliday',
    y='Sales',
    data=store1_data, 
    kind='box'
)

# %%
sb.factorplot(
    x='StateHoliday',
    y='Sales',
    data=store1_data, 
    kind='box'
)

# %% [markdown]
# > Check: See if there is a difference affecting sales on promotion days.

# %%
# TODO
sb.factorplot(
    x='Promo',
    y='Sales',
    data=store1_data, 
    kind='box'
)

# %% [markdown]
# Lastly, we want to identify larger-scale trends in our data. How did sales change from 2014 to 2015? Were there any particularly interesting outliers in terms of sales or customer visits?

# %%
# Filter to days store 1 was open
store1_open_data = store1_data[store1_data.Open==1]
store1_open_data[['Sales']].plot()

# %%
store1_open_data[['Customers']].plot()

# %% [markdown]
# In pandas, we can compute rolling average using the `pd.rolling_mean` or `pd.rolling_median` functions.

# %%
#store1_open_data = store1_open_data[::-1]
store1_open_data['Sales'].rolling(7).mean().plot()

# %%
store1_open_data['Sales'].rolling(7).median().plot()

# %% [markdown]
# ### Data REFINING Using Time Series Statistics

# %% [markdown]
# ### Autocorrelation

# %% [markdown]
# To measure how much the sales are correlated with each other, we want to compute the _autocorrelation_ of the 'Sales' column. In pandas, we do this we with the `autocorr` function:
#
# `autocorr` takes one argument, the `lag` which is how many prio data points should be used to compute the correlation. If we set the `lag` to 1, we compute the correlation between every point and the point directly preceding it. Setting `lag` to 10 computes the correlation between every point and the point 10 days earlier.

# %%
data['Sales'].resample('D').mean()
# Out:
# Date
# 2013-01-01      87.284560
# 2013-01-02    6233.030493
# 2013-01-03    5693.112108
# 2013-01-04    5954.218834
# 2013-01-05    5337.751570
# 2013-01-06     129.061883
# 2013-01-07    9710.177578
# 2013-01-08    7847.028700
# 2013-01-09    6947.626009
# 2013-01-10    6952.004484
# 2013-01-11    7210.139910
# 2013-01-12    5396.852915
# 2013-01-13     129.194619
# 2013-01-14    5279.630493
# 2013-01-15    4944.027803
# 2013-01-16    4747.103139
# 2013-01-17    4830.999103
# 2013-01-18    5504.044843
# 2013-01-19    5390.306726
# 2013-01-20     135.964126
# 2013-01-21    7857.465471
# 2013-01-22    7462.142601
# 2013-01-23    6947.590135
# 2013-01-24    6672.498655
# 2013-01-25    6978.286099
# 2013-01-26    5245.533632
# 2013-01-27     128.114798
# 2013-01-28    5272.378475
# 2013-01-29    4890.285202
# 2013-01-30    5300.250224
#                  ...
# 2015-07-02    7575.150673
# 2015-07-03    7650.572197
# 2015-07-04    5429.843946
# 2015-07-05     241.478027
# ...

# %%
for i in range(0,7):
    print 'Lag =',i,'  Autocorrelation =',data['Sales'].resample('D').mean().autocorr(lag=i)

print data['Sales'].resample('D').mean().autocorr(lag=7)
print data['Sales'].resample('D').mean().autocorr(lag=14)
print data['Sales'].resample('D').mean().autocorr(lag=21)
print data['Sales'].resample('D').mean().autocorr(lag=28)
# Out:
# Lag = 0   Autocorrelation = 1.0
# Lag = 1   Autocorrelation = -0.0258582760064
# Lag = 2   Autocorrelation = -0.0774434885663
# Lag = 3   Autocorrelation = 0.0116002982781
# Lag = 4   Autocorrelation = -0.0622513888638
# Lag = 5   Autocorrelation = -0.192355899471
# Lag = 6   Autocorrelation = -0.186080842166
# 0.557489358874
# 0.741900461325
# 0.60399893015
# 0.718112116053

# %% [markdown]
# ### Rolling Averages

# %% [markdown]
# If we want to investigate trends over time in sales, as always, we will start by computing simple aggregates.  What were the mean and median sales for each month and year?
#
# In Pandas, this is performed using the `resample` command, which is very similar to the `groupby` command. It allows us to group over different time intervals.
#
# We can use `data.resample` and provide as arguments:
#     - The level on which to roll-up to, 'D' for day, 'W' for week, 'M' for month, 'A' for year
#     - What aggregation to perform: 'mean', 'median', 'sum', etc.

# %%
data[['Sales']].resample('M').apply(['median', 'mean'])
# Out:
#              Sales
#             median         mean
# Date
# 2013-01-31  5194.0  5211.555578
# 2013-02-28  5421.5  5494.371397
# 2013-03-31  5844.0  5820.349168
# 2013-04-30  5464.0  5483.749836
# 2013-05-31  5585.0  5364.127383
# 2013-06-30  5428.0  5402.162960
# 2013-07-31  5826.0  6042.062260
# 2013-08-31  5624.0  5729.574049
# 2013-09-30  5294.0  5322.988430
# 2013-10-31  5446.0  5429.258788
# 2013-11-30  5886.5  5864.601614
# 2013-12-31  6566.0  6703.618140
# 2014-01-31  5415.0  5431.875799
# 2014-02-28  5660.0  5731.091512
# 2014-03-31  5500.0  5584.257312
# 2014-04-30  5820.5  5815.993333
# 2014-05-31  5723.0  5632.670534
# 2014-06-30  5735.5  5681.526188
# 2014-07-31  5935.0  5999.403381
# 2014-08-31  5645.0  5649.421252
# 2014-09-30  5739.0  5865.104029
# 2014-10-31  5726.0  5665.564878
# 2014-11-30  6337.5  6179.249661
# 2014-12-31  6915.0  6973.282456
# 2015-01-31  5862.0  5752.747866
# 2015-02-28  5732.0  5710.296541
# 2015-03-31  5910.0  5949.130132
# ...

# %% [markdown]
# While identifying the monthly averages is useful, we often want to compare the sales data of a date to a smaller window. To understand holidays sales, we don't want to compare late December with the entire month, but perhaps with a few days surrounding it. We can do this using rolling averages.
#
# In pandas, we can compute rolling average using the `pd.rolling_mean` or `pd.rolling_median` functions.

# %%
data[['Sales']].resample('D').mean().rolling(window=3, center=True).mean().head()
# Out:
#                   Sales
# Date
# 2013-01-01          NaN
# 2013-01-02  4004.475720
# 2013-01-03  5960.120478
# 2013-01-04  5661.694170
# 2013-01-05  3807.010762

# %% [markdown]
# `rolling_mean` (as well as `rolling_median`) takes these important parameters:
#     - the first is the series to aggregate
#     - `window` is the number of days to include in the average
#     - `center` is whether the window should be centered on the date or use data prior to that date
#     - `freq` is on what level to roll-up the averages to (as used in `resample`). Either `D` for day, `M` for month or `A` for year, etc.

# %% [markdown]
# Instead of plotting the full timeseries, we can plot the rolling mean instead, which smooths random changes in sales as well as removing outliers, helping us identify larger trends.

# %%
data[['Sales']].resample('D').mean().rolling(window=10, center=True).mean().plot()

# %% [markdown]
# ### Pandas Window functions
# Pandas `rolling_mean` and `rolling_median` are only two examples of Pandas window function capabilities. Window functions are operate on a set of N consecutive rows (a window) and produce an output.
#
# In addition to `rolling_mean` and `rolling_median`, there are `rolling_sum`, `rolling_min`, `rolling_max`... and many more.
#
# Another common one is `diff`, which takes the difference over time. `pd.diff` takes one arugment, `periods`, which is how many rows prior to use for the difference.

# %%
data['Sales'].diff(periods=1).head()
# Out:
# Date
# 2015-07-31       NaN
# 2015-07-31     801.0
# 2015-07-31    2250.0
# 2015-07-31    5681.0
# 2015-07-31   -9173.0
# Name: Sales, dtype: float64

# %% [markdown]
# ### Pandas expanding functions
#
# In addition to the set of `rolling_*` functions, Pandas also provides a similar collection of `expanding_*` functions, which, instead of using a window of N values, use all values up until that time.

# %%
# computes the average sales, from the first date _until_ the date specified.
data[['Sales']].resample('D').mean().expanding().mean().plot()

# %% [markdown]
# ## Exercises

# %% [markdown]
# > Plot the distribution of sales by month and compare the effect of promotions

# %%
# Sales by month

print data[['Sales']].resample('M').mean().head()
data[['Sales']].resample('M').mean().plot()
# Out:
#                   Sales
# Date
# 2013-01-31  5211.555578
# 2013-02-28  5494.371397
# 2013-03-31  5820.349168
# 2013-04-30  5483.749836
# 2013-05-31  5364.127383

# %%
# Explore Promo data

data[['Promo']].resample('D').mean()
# Out:
#             Promo
# Date
# 2013-01-01      0
# 2013-01-02      0
# 2013-01-03      0
# 2013-01-04      0
# 2013-01-05      0
# 2013-01-06      0
# 2013-01-07      1
# 2013-01-08      1
# 2013-01-09      1
# 2013-01-10      1
# 2013-01-11      1
# 2013-01-12      0
# 2013-01-13      0
# 2013-01-14      0
# 2013-01-15      0
# 2013-01-16      0
# 2013-01-17      0
# 2013-01-18      0
# 2013-01-19      0
# 2013-01-20      0
# 2013-01-21      1
# 2013-01-22      1
# 2013-01-23      1
# 2013-01-24      1
# 2013-01-25      1
# 2013-01-26      0
# 2013-01-27      0
# 2013-01-28      0
# 2013-01-29      0
# 2013-01-30      0
# ...           ...
# 2015-07-02      1
# 2015-07-03      1
# 2015-07-04      0
# 2015-07-05      0
# 2015-07-06      0
# 2015-07-07      0
# 2015-07-08      0
# 2015-07-09      0
# 2015-07-10      0
# 2015-07-11      0
# 2015-07-12      0
# 2015-07-13      1
# 2015-07-14      1
# 2015-07-15      1
# 2015-07-16      1
# 2015-07-17      1
# 2015-07-18      0
# ...

# %%
# Promo days by month

data[['Promo']].resample('D').mean().resample('M').sum()
# Out:
#             Promo
# Date
# 2013-01-31     10
# 2013-02-28     10
# 2013-03-31     15
# 2013-04-30     12
# 2013-05-31     13
# 2013-06-30     10
# 2013-07-31     13
# 2013-08-31     12
# 2013-09-30     10
# 2013-10-31     10
# 2013-11-30     10
# 2013-12-31     10
# 2014-01-31     10
# 2014-02-28     10
# 2014-03-31     11
# 2014-04-30     12
# 2014-05-31     12
# 2014-06-30     11
# 2014-07-31     13
# 2014-08-31     11
# 2014-09-30     12
# 2014-10-31     13
# 2014-11-30     15
# 2014-12-31     10
# 2015-01-31     15
# 2015-02-28     10
# 2015-03-31     12
# 2015-04-30     12
# 2015-05-31     11
# 2015-06-30     12
# 2015-07-31     13

# %%
# Promo vs Non-promo sales

sales_mean = data[['Promo','Sales']].resample('D').mean()

sb.factorplot(
    x='Promo',
    y='Sales',
    data=sales_mean, 
    kind='box'
)

# %%
# Taken away public holidays

store_all_nonholiday_data = data[data.StateHoliday=='0'][['Promo','Sales']].resample('D').mean()
print store_all_nonholiday_data.head(12)

sb.factorplot(
    x='Promo',
    y='Sales',
    data=store_all_nonholiday_data, 
    kind='box'
)
# Out:
#             Promo        Sales
# Date
# 2013-01-02    0.0  6233.030493
# 2013-01-03    0.0  5693.112108
# 2013-01-04    0.0  5954.218834
# 2013-01-05    0.0  5337.751570
# 2013-01-06    0.0   166.191067
# 2013-01-07    1.0  9710.177578
# 2013-01-08    1.0  7847.028700
# 2013-01-09    1.0  6947.626009
# 2013-01-10    1.0  6952.004484
# 2013-01-11    1.0  7210.139910
# 2013-01-12    0.0  5396.852915
# 2013-01-13    0.0   129.194619

# %%
# Take away Sundays 

store_all_nonholiday_data = data[(data.StateHoliday=='0')&(data.DayOfWeek!=7)][['Promo','Sales']].resample('D').mean()
print store_all_nonholiday_data.head(12)   #  !! The above did not delete the Sunday line
store_all_nonholiday_data = store_all_nonholiday_data.dropna()
# Out:
#             Promo        Sales
# Date
# 2013-01-02    0.0  6233.030493
# 2013-01-03    0.0  5693.112108
# 2013-01-04    0.0  5954.218834
# 2013-01-05    0.0  5337.751570
# 2013-01-06    NaN          NaN
# 2013-01-07    1.0  9710.177578
# 2013-01-08    1.0  7847.028700
# 2013-01-09    1.0  6947.626009
# 2013-01-10    1.0  6952.004484
# 2013-01-11    1.0  7210.139910
# 2013-01-12    0.0  5396.852915
# 2013-01-13    NaN          NaN

# %%
sb.factorplot(
    x='Promo',
    y='Sales',
    data=store_all_nonholiday_data, 
    kind='box'
)

# %%
store_all_nonholiday_data[store_all_nonholiday_data.Promo==0]['Sales'].describe().round(1)
# Out:
# count      432.0
# mean      5892.0
# std        911.9
# min          0.0
# 25%       5415.6
# 50%       5713.2
# 75%       6124.0
# max      12870.0
# Name: Sales, dtype: float64

# %%
store_all_nonholiday_data[store_all_nonholiday_data.Promo==1]['Sales'].describe().round(1)
# Out:
# count      353.0
# mean      8213.8
# std       1237.7
# min       6387.0
# 25%       7259.6
# 50%       7823.0
# 75%       9067.0
# max      14012.2
# Name: Sales, dtype: float64

# %% [markdown]
# > Are sales more correlated with the prior date, a similar date last year, or a similar date last month?

# %%
for i in [1,7,28,364]:
    print 'Lag =','{:>3}   {}'.format(i,'Autocorrelation ='),data['Sales'].resample('D').mean().autocorr(lag=i)     
    
# Lag=1      previous day
# Lag=7      same day of previous week
# Lag=28     same day of the week in previous month
# Lag=364    same day of the week 12 months ago
# Out:
# Lag =   1   Autocorrelation = -0.0258582760064
# Lag =   7   Autocorrelation = 0.557489358874
# Lag =  28   Autocorrelation = 0.718112116053
# Lag = 364   Autocorrelation = 0.756613221965

# %% [markdown]
# > Plot the 15 day rolling mean of customers in the stores

# %%
data[['Customers']].resample('D').mean().rolling(window=15, center=True).mean().plot()

# %% [markdown]
# > Identify the date with largest drop in sales from the same date in the previous month

# %%
# I use weekly mean to take away the effect of holidays
print data['Sales'].resample('W').mean().diff(periods=4).min()
print data['Sales'].resample('W').mean().diff(periods=4).idxmin().date()
# Out:
# -5031.95797566
# 2014-01-19

# %% [markdown]
# > Compute the total sales up until Dec. 2014

# %%
data[['Sales']].resample('D').sum().expanding().sum().loc['2014-12-31']
# Out:
# Sales    4.483681e+09
# Name: 2014-12-31 00:00:00, dtype: float64

# %% [markdown]
# > When were the largest differences between 15-day moving/rolling averages?
# > HINT: Using `rolling_mean` and `diff`

# %%
data['Sales'].resample('D').mean().rolling(window=15, center=True).mean().diff(periods=15).plot()

# %%
print data['Sales'].resample('D').mean().rolling(window=15, center=True).mean().diff(periods=15).max()
print data['Sales'].resample('D').mean().rolling(window=15, center=True).mean().diff(periods=15).min()
print data['Sales'].resample('D').mean().rolling(window=15, center=True).mean().diff(periods=15).idxmin().date()
# Out:
# 2360.71322638
# -3625.72125561
# 2013-12-31

# %%
# a different way

print data['Sales'].resample('D').mean().rolling(window=15, center=True).mean().diff(periods=15).abs().idxmax().date()
print data['Sales'].resample('D').mean().rolling(window=15, center=True).mean().diff(periods=15).loc[data['Sales'].resample('D').mean().rolling(window=15, center=True).mean().diff(periods=15).abs().idxmax()]
# Out:
# 2013-12-31
# -3625.72125561

# %%
# Same as above

diff_15d = data['Sales'].resample('D').mean().rolling(window=15, center=True).mean().diff(periods=15)
print diff_15d.abs().idxmax().date()
print diff_15d.loc[diff_15d.abs().idxmax().date()]
# Out:
# 2013-12-31
# -3625.72125561
