# %% [markdown]
# ### Class 7- Starter code

# %%
import numpy as np
import pandas as pd
from sklearn import linear_model, metrics

# %% [markdown]
# ### Create sample data and fit a model

# %%
df = pd.DataFrame({'x': range(100), 'y': range(100)})
biased_df  = df.copy()
biased_df.loc[:20, 'x'] = 1
biased_df.loc[:20, 'y'] = 1

def append_jitter(series):
    jitter = np.random.random_sample(size=100)
    return series + jitter

df['x'] = append_jitter(df.x)
df['y'] = append_jitter(df.y)
biased_df['x'] = append_jitter(biased_df.x)
biased_df['y'] = append_jitter(biased_df.y)

# %%
biased_df.head(100)
# Out:
#             x          y
# 0    1.750282   1.951180
# 1    1.506911   1.045775
# 2    1.169209   1.170346
# 3    1.886087   1.851784
# 4    1.561639   1.543202
# 5    1.533204   1.664606
# 6    1.168309   1.720108
# 7    1.179142   1.548226
# 8    1.214172   1.335108
# 9    1.037930   1.130273
# 10   1.833000   1.499473
# 11   1.275291   1.484812
# 12   1.353787   1.012120
# 13   1.183090   1.676030
# 14   1.420423   1.584590
# 15   1.108716   1.764610
# 16   1.856325   1.615629
# 17   1.569148   1.738790
# 18   1.890486   1.436285
# 19   1.249997   1.974582
# 20   1.280985   1.123163
# 21  21.733087  21.481995
# 22  22.219351  22.382321
# 23  23.324507  23.839001
# 24  24.764464  24.369157
# 25  25.355407  25.845794
# 26  26.991617  26.547688
# 27  27.705229  27.233806
# 28  28.462196  28.842593
# 29  29.638374  29.404341
# ..        ...        ...
# 70  70.215732  70.732138
# 71  71.428889  71.342185
# 72  72.838354  72.107429
# 73  73.984257  73.359161
# 74  74.955419  74.630277
# 75  75.292494  75.458258
# 76  76.786353  76.398929
# 77  77.449865  77.355291
# 78  78.555451  78.914037
# 79  79.859355  79.327326
# 80  80.988684  80.663809
# 81  81.080732  81.889685
# 82  82.712939  82.716858
# 83  83.736257  83.490387
# 84  84.509252  84.494154
# 85  85.328375  85.750700
# 86  86.335492  86.544687
# 87  87.483904  87.864452
# 88  88.361451  88.651709
# 89  89.350325  89.027892
# 90  90.483577  90.312842
# 91  91.865670  91.768777
# 92  92.597733  92.418247
# 93  93.039364  93.058434
# 94  94.122996  94.740048
# 95  95.303828  95.096358
# 96  96.615856  96.498413
# 97  97.656019  97.282845
# 98  98.359126  98.971066
# 99  99.191198  99.552926
#
# [100 rows x 2 columns]

# %%
np.abs(((df['y']-df['x'])**2).sum())
# Out:
# 16.223192569742935

# %%
## fit
lm = linear_model.LinearRegression().fit(df[['x']], df['y'])
print metrics.mean_squared_error(df['y'], lm.predict(df[['x']]))
# Out:
# 0.156618552272

# %%
## biased fit
lm = linear_model.LinearRegression().fit(biased_df[['x']], biased_df['y'])
print metrics.mean_squared_error(biased_df['y'], lm.predict(biased_df[['x']]))
# Out:
# 0.151233333886

# %% [markdown]
# ## Cross validation
# #### Intro to cross validation with bike share data from last time. We will be modeling casual ridership.

# %%
from sklearn import cross_validation
wd = '../../assets/dataset/'
bikeshare = pd.read_csv(wd + 'bikeshare.csv')
# Out:
# C:\Users\Andrew\Anaconda2\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# #### Create dummy variables and set outcome (dependent) variable

# %%
weather = pd.get_dummies(bikeshare.weathersit, prefix='weather')
modeldata = bikeshare[['temp', 'hum']].join(weather[['weather_1', 'weather_2', 'weather_3']])
y = bikeshare.casual

# %%
modeldata
# Out:
#        temp   hum  weather_1  weather_2  weather_3
# 0      0.24  0.81          1          0          0
# 1      0.22  0.80          1          0          0
# 2      0.22  0.80          1          0          0
# 3      0.24  0.75          1          0          0
# 4      0.24  0.75          1          0          0
# 5      0.24  0.75          0          1          0
# 6      0.22  0.80          1          0          0
# 7      0.20  0.86          1          0          0
# 8      0.24  0.75          1          0          0
# 9      0.32  0.76          1          0          0
# 10     0.38  0.76          1          0          0
# 11     0.36  0.81          1          0          0
# 12     0.42  0.77          1          0          0
# 13     0.46  0.72          0          1          0
# 14     0.46  0.72          0          1          0
# 15     0.44  0.77          0          1          0
# 16     0.42  0.82          0          1          0
# 17     0.44  0.82          0          1          0
# 18     0.42  0.88          0          0          1
# 19     0.42  0.88          0          0          1
# 20     0.40  0.87          0          1          0
# 21     0.40  0.87          0          1          0
# 22     0.40  0.94          0          1          0
# 23     0.46  0.88          0          1          0
# 24     0.46  0.88          0          1          0
# 25     0.44  0.94          0          1          0
# 26     0.42  1.00          0          1          0
# 27     0.46  0.94          0          1          0
# 28     0.46  0.94          0          1          0
# 29     0.42  0.77          0          0          1
# ...     ...   ...        ...        ...        ...
# 17349  0.24  0.44          0          1          0
# 17350  0.34  0.61          1          0          0
# 17351  0.22  0.47          1          0          0
# 17352  0.20  0.51          1          0          0
# 17353  0.20  0.55          1          0          0
# 17354  0.20  0.51          1          0          0
# 17355  0.18  0.55          1          0          0
# 17356  0.18  0.55          1          0          0
# 17357  0.16  0.59          1          0          0
# 17358  0.16  0.59          1          0          0
# 17359  0.14  0.69          1          0          0
# 17360  0.16  0.64          1          0          0
# 17361  0.16  0.64          1          0          0
# 17362  0.16  0.64          1          0          0
# 17363  0.14  0.69          1          0          0
# 17364  0.18  0.64          0          1          0
# 17365  0.20  0.69          0          1          0
# 17366  0.22  0.60          0          1          0
# 17367  0.24  0.56          0          1          0
# 17368  0.26  0.44          0          1          0
# 17369  0.28  0.45          0          1          0
# 17370  0.28  0.45          0          1          0
# 17371  0.26  0.48          0          1          0
# 17372  0.26  0.48          0          1          0
# 17373  0.26  0.48          0          1          0
# 17374  0.26  0.60          0          1          0
# 17375  0.26  0.60          0          1          0
# 17376  0.26  0.60          1          0          0
# 17377  0.26  0.56          1          0          0
# 17378  0.26  0.65          1          0          0
#
# [17379 rows x 5 columns]

# %% [markdown]
# #### Create a cross valiation with 5 folds

# %%
for k in range(2,10,1):
    #k=5
    kf = cross_validation.KFold(len(modeldata), n_folds=k, shuffle=True)
    mse_values_train = []
    mse_values = []
    scores = []
    n=0
    for train_index, test_index in kf:
        lm = linear_model.LinearRegression().fit(modeldata.iloc[train_index], y.iloc[train_index])
        mse_values_train.append(metrics.mean_squared_error(y.iloc[train_index], lm.predict(modeldata.iloc[train_index])))
        mse_values.append(metrics.mean_squared_error(y.iloc[test_index], lm.predict(modeldata.iloc[test_index])))
        scores.append(lm.score(modeldata, y))
        print train_index, test_index, mse_values_train[n].round(6), mse_values[n].round(6), scores[n].round(6)
        n += 1
    print "~~~~ SUMMARY OF CROSS VALIDATION {} FOLDS~~~~".format(k)
    print np.mean(mse_values_train)
    print 'Mean of MSE for all folds:', np.mean(mse_values)
    print 'Mean of R2 for all folds:', np.mean(scores)
    print
# Out:
# [    8     9    10 ..., 17373 17374 17376] [    0     1     2 ..., 17375 17377 17378] 1680.377167 1665.356378 0.311817
# [    0     1     2 ..., 17375 17377 17378] [    8     9    10 ..., 17373 17374 17376] 1664.202097 1681.559598 0.311812
# ~~~~ SUMMARY OF CROSS VALIDATION 2 FOLDS~~~~
# 1672.28963177
# Mean of MSE for all folds: 1673.45798823
# Mean of R2 for all folds: 0.311814385883
#
# [    0     1     2 ..., 17373 17376 17377] [   11    15    18 ..., 17374 17375 17378] 1676.470628 1665.379847 0.311855
# [    0     1     4 ..., 17376 17377 17378] [    2     3     6 ..., 17368 17372 17373] 1698.15863 1621.702928 0.311897
# [    2     3     6 ..., 17374 17375 17378] [    0     1     4 ..., 17371 17376 17377] 1642.73922 1732.535169 0.311898
# ~~~~ SUMMARY OF CROSS VALIDATION 3 FOLDS~~~~
# 1672.45615922
# Mean of MSE for all folds: 1673.20598131
# Mean of R2 for all folds: 0.311883186747
#
# [    0     1     2 ..., 17375 17376 17378] [    4     9    13 ..., 17362 17366 17377] 1681.527358 1646.565447 0.31185
# [    1     4     5 ..., 17376 17377 17378] [    0     2     3 ..., 17365 17371 17375] 1681.099981 1647.252786 0.311911
# [    0     2     3 ..., 17375 17376 17377] [    1     5     7 ..., 17373 17374 17378] 1660.719114 1708.705079 0.311879
# [    0     1     2 ..., 17375 17377 17378] [    8    16    19 ..., 17367 17370 17376] 1666.402437 1691.837353 0.311861
# ~~~~ SUMMARY OF CROSS VALIDATION 4 FOLDS~~~~
# 1672.43722241
# Mean of MSE for all folds: 1673.59016644
# Mean of R2 for all folds: 0.311875366755
#
# [    0     1     2 ..., 17376 17377 17378] [    3    11    14 ..., 17352 17356 17367] 1639.51438 1804.951021 0.311925
# [    0     2     3 ..., 17375 17376 17377] [    1     6    17 ..., 17362 17373 17378] 1660.551528 1721.208181 0.311892
# [    0     1     2 ..., 17376 17377 17378] [    4     5     7 ..., 17370 17371 17374] 1686.1072 1619.332456 0.311865
# [    0     1     2 ..., 17374 17376 17378] [   15    20    26 ..., 17372 17375 17377] 1667.659911 1692.677722 0.311901
# [    1     3     4 ..., 17375 17377 17378] [    0     2     8 ..., 17357 17369 17376] 1708.573615 1529.164323 0.311886
# ~~~~ SUMMARY OF CROSS VALIDATION 5 FOLDS~~~~
# 1672.48132668
# Mean of MSE for all folds: 1673.46674035
# Mean of R2 for all folds: 0.311893724023
#
# [    1     2     3 ..., 17375 17376 17377] [    0     5    13 ..., 17359 17373 17378] 1677.239523 1650.16617 0.311875
# [    0     1     2 ..., 17376 17377 17378] [   11    15    16 ..., 17334 17365 17370] 1686.087099 1605.22179 0.311924
# [    0     1     2 ..., 17375 17377 17378] [    4     6     9 ..., 17369 17372 17376] 1669.948833 1685.976994 0.311918
# [    0     2     4 ..., 17375 17376 17378] [    1     3     8 ..., 17360 17361 17377] 1687.619091 1597.436579 0.31193
# [    0     1     3 ..., 17376 17377 17378] [    2     7    17 ..., 17368 17371 17374] 1658.966509 1741.82815 0.311855
# [    0     1     2 ..., 17376 17377 17378] [   10    19    31 ..., 17364 17366 17375] 1655.094963 1760.732663 0.311886
# ~~~~ SUMMARY OF CROSS VALIDATION 6 FOLDS~~~~
# 1672.49266969
# Mean of MSE for all folds: 1673.56039083
# Mean of R2 for all folds: 0.311898156374
#
# [    0     1     2 ..., 17376 17377 17378] [    5     7    12 ..., 17373 17374 17375] 1688.615336 1577.014219 0.311898
# [    0     1     2 ..., 17376 17377 17378] [   16    21    25 ..., 17357 17364 17372] 1641.554833 1859.515007 0.311888
# [    0     1     3 ..., 17375 17376 17377] [    2    10    13 ..., 17349 17352 17378] 1670.123708 1687.759563 0.311909
# [    0     1     2 ..., 17376 17377 17378] [    3    19    20 ..., 17345 17359 17362] 1683.458549 1608.324157 0.311876
# [    2     3     5 ..., 17376 17377 17378] [    0     1     4 ..., 17367 17368 17369] 1692.050295 1556.250695 0.311907
# [    0     1     2 ..., 17375 17376 17378] [    6     9    17 ..., 17370 17371 17377] 1687.439971 1584.050001 0.311896
# [    0     1     2 ..., 17375 17377 17378] [    8    11    14 ..., 17365 17366 17376] 1643.965844 1846.380371 0.311814
# ~~~~ SUMMARY OF CROSS VALIDATION 7 FOLDS~~~~
# 1672.45836225
# Mean of MSE for all folds: 1674.18485909
# Mean of R2 for all folds: 0.311883960499
#
# [    0     1     2 ..., 17375 17376 17378] [   16    17    48 ..., 17365 17370 17377] 1665.267029 1724.200556 0.311912
# [    0     1     2 ..., 17376 17377 17378] [    8    22    23 ..., 17360 17361 17366] 1679.039516 1627.838438 0.311911
# [    0     1     2 ..., 17376 17377 17378] [    3     4    25 ..., 17346 17351 17359] 1673.659921 1665.132594 0.311929
# [    0     1     2 ..., 17375 17376 17377] [    5    12    13 ..., 17358 17362 17378] 1692.568053 1532.809825 0.311926
# [    0     1     2 ..., 17376 17377 17378] [   18    37    38 ..., 17355 17371 17372] 1684.861447 1586.992856 0.311914
# [    0     1     2 ..., 17376 17377 17378] [    6    15    26 ..., 17350 17363 17364] 1676.360556 1646.326092 0.311924
# [    0     1     3 ..., 17375 17377 17378] [    2     9    11 ..., 17344 17356 17376] 1652.49836 1813.618423 0.311912
# [    2     3     4 ..., 17376 17377 17378] [    0     1     7 ..., 17373 17374 17375] 1656.084358 1788.386396 0.311919
# ~~~~ SUMMARY OF CROSS VALIDATION 8 FOLDS~~~~
# 1672.54240508
# Mean of MSE for all folds: 1673.16314734
# Mean of R2 for all folds: 0.31191861522
#
# [    0     1     2 ..., 17376 17377 17378] [    3    13    26 ..., 17364 17372 17374] 1689.08626 1540.918977 0.311917
# [    0     1     2 ..., 17375 17376 17378] [    4    10    11 ..., 17341 17356 17377] 1668.193037 1708.308947 0.311906
# [    0     1     2 ..., 17376 17377 17378] [   14    16    21 ..., 17357 17359 17373] 1680.576909 1608.952836 0.311919
# [    0     1     3 ..., 17374 17377 17378] [    2     5     8 ..., 17368 17375 17376] 1641.341941 1922.747369 0.311923
# [    1     2     3 ..., 17376 17377 17378] [    0    19    32 ..., 17365 17367 17371] 1682.721247 1591.962704 0.311912
# [    0     1     2 ..., 17375 17376 17377] [   15    51    56 ..., 17360 17369 17378] 1688.622228 1544.926077 0.311904
# [    0     1     2 ..., 17376 17377 17378] [    9    12    17 ..., 17348 17351 17354] 1652.561506 1833.486852 0.3119
# [    0     1     2 ..., 17376 17377 17378] [    7    23    28 ..., 17363 17366 17370] 1663.256445 1747.716084 0.31191
# [    0     2     3 ..., 17376 17377 17378] [    1     6    20 ..., 17339 17344 17350] 1686.33401 1563.329484 0.311899
# ~~~~ SUMMARY OF CROSS VALIDATION 9 FOLDS~~~~
# 1672.52150926
# Mean of MSE for all folds: 1673.59437002
# Mean of R2 for all folds: 0.311910084341

# %%
kf = cross_validation.KFold(len(modeldata), n_folds=5, shuffle=True)

# %%
mse_values = []
scores = []
n= 0
print "~~~~ CROSS VALIDATION each fold ~~~~"
for train_index, test_index in kf:
    lm = linear_model.LinearRegression().fit(modeldata.iloc[train_index], y.iloc[train_index])
    mse_values.append(metrics.mean_squared_error(y.iloc[test_index], lm.predict(modeldata.iloc[test_index])))
    scores.append(lm.score(modeldata, y))
    n+=1
    print 'Model', n
    print 'MSE:', mse_values[n-1]
    print 'R2:', scores[n-1]


print "~~~~ SUMMARY OF CROSS VALIDATION ~~~~"
print 'Mean of MSE for all folds:', np.mean(mse_values)
print 'Mean of R2 for all folds:', np.mean(scores)
# Out:
# ~~~~ CROSS VALIDATION each fold ~~~~
# Model 1
# MSE: 1865.80650524
# R2: 0.311904370208
# Model 2
# MSE: 1655.81315233
# R2: 0.311914626525
# Model 3
# MSE: 1600.73968669
# R2: 0.311904375989
# Model 4
# MSE: 1762.80043928
# R2: 0.311842842944
# Model 5
# MSE: 1482.73868172
# R2: 0.311876047373
# ~~~~ SUMMARY OF CROSS VALIDATION ~~~~
# Mean of MSE for all folds: 1673.57969305
# Mean of R2 for all folds: 0.311888452608

# %%
lm = linear_model.LinearRegression().fit(modeldata, y)
print "~~~~ Single Model ~~~~"
print 'MSE of single model:', metrics.mean_squared_error(y, lm.predict(modeldata))
print 'R2: ', lm.score(modeldata, y)
# Out:
# ~~~~ Single Model ~~~~
# MSE of single model: 1672.58110765
# R2:  0.311934605989

# %% [markdown]
# ### Check
# While the cross validated approach here generated more overall error, which of the two approaches would predict new data more accurately: the single model or the cross validated, averaged one? Why?

# %% [markdown]
# Answer: Cross validated, averaged one. It is just safer in avoiding the overfitting problem.

# %% [markdown]
# ### There are ways to improve our model with regularization.
# Let's check out the effects on MSE and R2

# %%
lm = linear_model.LinearRegression().fit(modeldata, y)
print "~~~ OLS ~~~"
print 'OLS MSE: ', metrics.mean_squared_error(y, lm.predict(modeldata))
print 'OLS R2:', lm.score(modeldata, y)

lm = linear_model.Lasso().fit(modeldata, y)
print "~~~ Lasso ~~~"
print 'Lasso MSE: ', metrics.mean_squared_error(y, lm.predict(modeldata))
print 'Lasso R2:', lm.score(modeldata, y)

lm = linear_model.Ridge().fit(modeldata, y)
print "~~~ Ridge ~~~"
print 'Ridge MSE: ', metrics.mean_squared_error(y, lm.predict(modeldata))
print 'Ridge R2:', lm.score(modeldata, y)
# Out:
# ~~~ OLS ~~~
# OLS MSE:  1672.58110765
# OLS R2: 0.311934605989
# ~~~ Lasso ~~~
# Lasso MSE:  1725.41581608
# Lasso R2: 0.290199495922
# ~~~ Ridge ~~~
# Ridge MSE:  1672.60490113
# Ridge R2: 0.311924817843

# %% [markdown]
# ### Figuring out the alphas can be done by "hand"

# %%
alphas = np.logspace(-10, 10, 21)
for a in alphas:
    print 'Alpha:', a
    lm = linear_model.Ridge(alpha=a)
    lm.fit(modeldata, y)
    print lm.coef_
    print metrics.mean_squared_error(y, lm.predict(modeldata))
# Out:
# Alpha: 1e-10
# [ 112.68901765  -84.01121684  -24.68489063  -21.00314493  -21.71893628]
# 1672.58110765
# Alpha: 1e-09
# [ 112.68901765  -84.01121684  -24.68489061  -21.00314491  -21.71893626]
# 1672.58110765
# Alpha: 1e-08
# [ 112.68901765  -84.01121684  -24.6848904   -21.00314471  -21.71893606]
# 1672.58110765
# Alpha: 1e-07
# [ 112.68901763  -84.01121682  -24.68488837  -21.00314268  -21.71893403]
# 1672.58110765
# Alpha: 1e-06
# [ 112.68901745  -84.01121667  -24.68486804  -21.00312237  -21.71891373]
# 1672.58110765
# Alpha: 1e-05
# [ 112.68901562  -84.01121509  -24.68466472  -21.00291929  -21.71871079]
# 1672.58110765
# Alpha: 0.0001
# [ 112.68899732  -84.01119938  -24.68263174  -21.00088873  -21.71668162]
# 1672.58110765
# Alpha: 0.001
# [ 112.68881437  -84.01104228  -24.66232204  -20.98060316  -21.69640993]
# 1672.58110774
# Alpha: 0.01
# [ 112.68698753  -84.00947323  -24.46121539  -20.77973778  -21.49568404]
# 1672.58111645
# Alpha: 0.1
# [ 112.66896732  -83.99396383  -22.63109556  -18.95202277  -19.66942371]
# 1672.58185208
# Alpha: 1.0
# [ 112.50129738  -83.84805622  -13.38214934   -9.72671278  -10.46162477]
# 1672.60490113
# Alpha: 10.0
# [ 110.96062533  -82.49604961   -3.94431741   -0.51765034   -1.45024412]
# 1672.83347262
# Alpha: 100.0
# [ 97.69060562 -71.17602377  -0.31585194   1.18284675  -1.33281591]
# 1686.31830362
# Alpha: 1000.0
# [ 44.59923075 -30.85843772   5.07876321   0.05369643  -5.107457  ]
# 1937.81576044
# Alpha: 10000.0
# [ 7.03007064 -5.07733082  3.29039029 -1.2136063  -2.06842808]
# 2314.83675678
# Alpha: 100000.0
# [ 0.75195708 -0.56490872  0.52067881 -0.25075496 -0.26895254]
# 2415.77806566
# Alpha: 1000000.0
# [ 0.07576571 -0.05727511  0.05520142 -0.0273591  -0.02774349]
# 2429.28026459
# Alpha: 10000000.0
# [ 0.00758239 -0.00573569  0.0055535  -0.00276043 -0.00278317]
# 2430.68891798
# Alpha: 100000000.0
# [ 0.0007583  -0.00057365  0.00055569 -0.00027629 -0.00027841]
# 2430.83041212
# Alpha: 1000000000.0
# [  7.58303020e-05  -5.73659720e-05   5.55719458e-05  -2.76314619e-05
#   -2.78414555e-05]
# 2430.84456787
# Alpha: 10000000000.0
# [  7.58303603e-06  -5.73660542e-06   5.55722818e-06  -2.76317091e-06
#   -2.78415441e-06]
# 2430.84598351

# %% [markdown]
# ### Or we can use grid search to make this faster

# %%
from sklearn import grid_search

alphas = np.logspace(-10, 10, 21)
gs = grid_search.GridSearchCV(
    estimator=linear_model.Ridge(),
    param_grid={'alpha': alphas},
    scoring='neg_mean_squared_error')

gs.fit(modeldata, y)
# Out:
# C:\Users\Andrew\Anaconda2\lib\site-packages\sklearn\grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)
# GridSearchCV(cv=None, error_score='raise',
#        estimator=Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'alpha': array([  1.00000e-10,   1.00000e-09,   1.00000e-08,   1.00000e-07,
#          1.00000e-06,   1.00000e-05,   1.00000e-04,   1.00000e-03,
#          1.00000e-02,   1.00000e-01,   1.00000e+00,   1.00000e+01,
#          1.00000e+02,   1.00000e+03,   1.00000e+04,   1.00000e+05,
#          1.00000e+06,   1.00000e+07,   1.00000e+08,   1.00000e+09,
#          1.00000e+10])},
#        pre_dispatch='2*n_jobs', refit=True,
#        scoring='neg_mean_squared_error', verbose=0)

# %% [markdown]
# ##### Best score

# %%
gs.best_score_
# Out:
# -1814.0936913337962

# %% [markdown]
# ##### mean squared error here comes in negative, so let's make it positive.

# %%
-gs.best_score_
# Out:
# 1814.0936913337962

# %% [markdown]
# ##### explains which grid_search setup worked best

# %%
gs.best_estimator_
# Out:
# Ridge(alpha=10.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %% [markdown]
# ##### shows all the grid pairings and their performances.

# %%
for s in gs.grid_scores_:
    print s
# Out:
# mean: -1817.58711, std: 542.14315, params: {'alpha': 1e-10}
# mean: -1817.58711, std: 542.14315, params: {'alpha': 1.0000000000000001e-09}
# mean: -1817.58711, std: 542.14315, params: {'alpha': 1e-08}
# mean: -1817.58711, std: 542.14315, params: {'alpha': 9.9999999999999995e-08}
# mean: -1817.58711, std: 542.14315, params: {'alpha': 9.9999999999999995e-07}
# mean: -1817.58711, std: 542.14317, params: {'alpha': 1.0000000000000001e-05}
# mean: -1817.58707, std: 542.14331, params: {'alpha': 0.0001}
# mean: -1817.58663, std: 542.14477, params: {'alpha': 0.001}
# mean: -1817.58230, std: 542.15933, params: {'alpha': 0.01}
# mean: -1817.54318, std: 542.30102, params: {'alpha': 0.10000000000000001}
# mean: -1817.20111, std: 543.63587, params: {'alpha': 1.0}
# mean: -1814.09369, std: 556.35563, params: {'alpha': 10.0}
# mean: -1818.51694, std: 653.68607, params: {'alpha': 100.0}
# mean: -2125.58777, std: 872.45270, params: {'alpha': 1000.0}
# mean: -2458.08836, std: 951.30428, params: {'alpha': 10000.0}
# mean: -2532.21151, std: 962.80083, params: {'alpha': 100000.0}
# mean: -2541.38479, std: 963.98339, params: {'alpha': 1000000.0}
# mean: -2542.32833, std: 964.10141, params: {'alpha': 10000000.0}
# mean: -2542.42296, std: 964.11321, params: {'alpha': 100000000.0}
# mean: -2542.43242, std: 964.11439, params: {'alpha': 1000000000.0}
# mean: -2542.43337, std: 964.11450, params: {'alpha': 10000000000.0}

# %% [markdown]
# ### ACTIVITY

# %% [markdown]
# ## Gradient Descent

# %%
num_to_approach, start, steps, optimized = 6.5, 0., [-1, 1], False
while not optimized:
    current_distance = num_to_approach - start
    got_better = False
    next_steps = [start + i for i in steps]
    for n in next_steps:
        print n
        distance = np.abs(num_to_approach - n)
        if distance < current_distance:
            got_better = True
            print distance, 'is better than', current_distance
            current_distance = distance
            start = n
    if got_better:
        print 'found better solution! using', current_distance
    else:
        optimized = True
        print start, 'is closest to', num_to_approach
# Out:
# -1.0
# 1.0
# 5.5 is better than 6.5
# found better solution! using 5.5
# 0.0
# 2.0
# 4.5 is better than 5.5
# found better solution! using 4.5
# 1.0
# 3.0
# 3.5 is better than 4.5
# found better solution! using 3.5
# 2.0
# 4.0
# 2.5 is better than 3.5
# found better solution! using 2.5
# 3.0
# 5.0
# 1.5 is better than 2.5
# found better solution! using 1.5
# 4.0
# 6.0
# 0.5 is better than 1.5
# found better solution! using 0.5
# 5.0
# 7.0
# 6.0 is closest to 6.5

# %% [markdown]
# ### Bonus:
# implement a stopping point, similar to what n_iter would do in gradient descent when we've reached "good enough"

# %%
num_to_approach, start, steps, optimized = 6.5, 0., [-1, 1], False
n_iter = 0
while not optimized:
    n_iter += 1
    current_distance = np.abs(num_to_approach - start)
    got_better = False
    next_steps = [start + i for i in steps]
    print n_iter
    for n in next_steps:
        #print n
        distance = np.abs(num_to_approach - n)
        if distance <= current_distance:   # deliberately making the logic wrong here
            got_better = True
            print distance, 'is better than', current_distance
            current_distance = distance
            start = n
        #print n_iter,distance,current_distance
    if (got_better) & (n_iter < 1000):     # adding extra criterion to avoid infinite loop
        print 'found better solution! using distance =', current_distance, 'and start =',start
                # elif (distance == current_distance) & (n_iter < 1000):
                #     print 'continue finding closer solution until 1000th iteration'
    else:        
        optimized = True
        print start, 'is closest to', num_to_approach
# Out:
# 1
# 5.5 is better than 6.5
# found better solution! using distance = 5.5 and start = 1.0
# 2
# 4.5 is better than 5.5
# found better solution! using distance = 4.5 and start = 2.0
# 3
# 3.5 is better than 4.5
# found better solution! using distance = 3.5 and start = 3.0
# 4
# 2.5 is better than 3.5
# found better solution! using distance = 2.5 and start = 4.0
# 5
# 1.5 is better than 2.5
# found better solution! using distance = 1.5 and start = 5.0
# 6
# 0.5 is better than 1.5
# found better solution! using distance = 0.5 and start = 6.0
# 7
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 8
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 9
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 10
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 11
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 12
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 13
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 14
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 15
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 16
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 17
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 18
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 19
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 20
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 21
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 22
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 23
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 24
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 25
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 26
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 27
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 28
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 29
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 30
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 31
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 32
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 33
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 34
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 35
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 36
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 37
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 38
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 39
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 40
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 41
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 42
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 43
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 44
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 45
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 46
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 47
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 48
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 49
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 50
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 51
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 52
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 53
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 54
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 55
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 56
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 57
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 58
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 59
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 60
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 61
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 62
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 63
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 64
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 65
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 66
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 67
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 68
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 69
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 70
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 71
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 72
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 73
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 74
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 75
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 76
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 77
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 78
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 79
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 80
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 81
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 82
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 83
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 84
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 85
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 86
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 87
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 88
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 89
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 90
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 91
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 92
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 93
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 94
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 95
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 96
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 97
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 98
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 99
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 100
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 101
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 102
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 103
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 104
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 105
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 106
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 107
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 108
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 109
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 110
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 111
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 112
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 113
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 114
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 115
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 116
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 117
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 118
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 119
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 120
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 121
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 122
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 123
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 124
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 125
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 126
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 127
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 128
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 129
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 130
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 131
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 132
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 133
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 134
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 135
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 136
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 137
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 138
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 139
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 140
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 141
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 142
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 143
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 144
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 145
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 146
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 147
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 148
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 149
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 150
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 151
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 152
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 153
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 154
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 155
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 156
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 157
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 158
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 159
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 160
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 161
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 162
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 163
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 164
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 165
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 166
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 167
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 168
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 169
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 170
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 171
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 172
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 173
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 174
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 175
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 176
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 177
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 178
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 179
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 180
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 181
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 182
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 183
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 184
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 185
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 186
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 187
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 188
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 189
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 190
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 191
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 192
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 193
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 194
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 195
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 196
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 197
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 198
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 199
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 200
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 201
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 202
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 203
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 204
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 205
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 206
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 207
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 208
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 209
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 210
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 211
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 212
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 213
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 214
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 215
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 216
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 217
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 218
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 219
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 220
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 221
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 222
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 223
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 224
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 225
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 226
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 227
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 228
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 229
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 230
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 231
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 232
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 233
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 234
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 235
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 236
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 237
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 238
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 239
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 240
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 241
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 242
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 243
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 244
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 245
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 246
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 247
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 248
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 249
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 250
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 251
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 252
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 253
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 254
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 255
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 256
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 257
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 258
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 259
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 260
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 261
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 262
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 263
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 264
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 265
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 266
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 267
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 268
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 269
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 270
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 271
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 272
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 273
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 274
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 275
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 276
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 277
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 278
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 279
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 280
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 281
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 282
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 283
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 284
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 285
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 286
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 287
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 288
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 289
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 290
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 291
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 292
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 293
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 294
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 295
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 296
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 297
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 298
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 299
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 300
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 301
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 302
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 303
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 304
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 305
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 306
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 307
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 308
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 309
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 310
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 311
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 312
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 313
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 314
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 315
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 316
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 317
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 318
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 319
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 320
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 321
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 322
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 323
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 324
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 325
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 326
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 327
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 328
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 329
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 330
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 331
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 332
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 333
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 334
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 335
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 336
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 337
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 338
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 339
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 340
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 341
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 342
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 343
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 344
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 345
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 346
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 347
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 348
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 349
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 350
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 351
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 352
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 353
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 354
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 355
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 356
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 357
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 358
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 359
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 360
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 361
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 362
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 363
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 364
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 365
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 366
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 367
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 368
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 369
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 370
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 371
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 372
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 373
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 374
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 375
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 376
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 377
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 378
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 379
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 380
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 381
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 382
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 383
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 384
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 385
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 386
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 387
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 388
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 389
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 390
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 391
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 392
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 393
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 394
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 395
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 396
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 397
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 398
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 399
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 400
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 401
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 402
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 403
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 404
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 405
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 406
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 407
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 408
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 409
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 410
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 411
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 412
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 413
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 414
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 415
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 416
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 417
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 418
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 419
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 420
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 421
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 422
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 423
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 424
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 425
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 426
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 427
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 428
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 429
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 430
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 431
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 432
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 433
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 434
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 435
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 436
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 437
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 438
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 439
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 440
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 441
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 442
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 443
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 444
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 445
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 446
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 447
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 448
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 449
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 450
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 451
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 452
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 453
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 454
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 455
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 456
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 457
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 458
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 459
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 460
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 461
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 462
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 463
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 464
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 465
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 466
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 467
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 468
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 469
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 470
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 471
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 472
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 473
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 474
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 475
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 476
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 477
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 478
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 479
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 480
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 481
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 482
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 483
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 484
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 485
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 486
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 487
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 488
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 489
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 490
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 491
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 492
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 493
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 494
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 495
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 496
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 497
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 498
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 499
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 500
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 501
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 502
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 503
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 504
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 505
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 506
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 507
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 508
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 509
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 510
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 511
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 512
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 513
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 514
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 515
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 516
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 517
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 518
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 519
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 520
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 521
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 522
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 523
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 524
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 525
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 526
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 527
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 528
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 529
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 530
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 531
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 532
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 533
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 534
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 535
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 536
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 537
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 538
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 539
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 540
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 541
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 542
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 543
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 544
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 545
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 546
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 547
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 548
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 549
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 550
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 551
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 552
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 553
# 0.5 is better than 0.5
# ...
# 817
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 818
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 819
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 820
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 821
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 822
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 823
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 824
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 825
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 826
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 827
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 828
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 829
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 830
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 831
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 832
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 833
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 834
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 835
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 836
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 837
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 838
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 839
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 840
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 841
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 842
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 843
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 844
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 845
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 846
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 847
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 848
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 849
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 850
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 851
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 852
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 853
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 854
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 855
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 856
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 857
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 858
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 859
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 860
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 861
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 862
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 863
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 864
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 865
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 866
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 867
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 868
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 869
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 870
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 871
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 872
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 873
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 874
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 875
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 876
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 877
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 878
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 879
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 880
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 881
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 882
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 883
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 884
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 885
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 886
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 887
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 888
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 889
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 890
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 891
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 892
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 893
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 894
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 895
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 896
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 897
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 898
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 899
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 900
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 901
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 902
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 903
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 904
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 905
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 906
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 907
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 908
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 909
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 910
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 911
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 912
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 913
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 914
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 915
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 916
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 917
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 918
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 919
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 920
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 921
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 922
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 923
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 924
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 925
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 926
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 927
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 928
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 929
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 930
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 931
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 932
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 933
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 934
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 935
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 936
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 937
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 938
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 939
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 940
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 941
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 942
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 943
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 944
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 945
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 946
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 947
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 948
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 949
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 950
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 951
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 952
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 953
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 954
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 955
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 956
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 957
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 958
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 959
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 960
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 961
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 962
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 963
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 964
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 965
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 966
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 967
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 968
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 969
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 970
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 971
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 972
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 973
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 974
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 975
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 976
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 977
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 978
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 979
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 980
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 981
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 982
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 983
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 984
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 985
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 986
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 987
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 988
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 989
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 990
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 991
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 992
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 993
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 994
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 995
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 996
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 997
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 998
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 6.0
# 999
# 0.5 is better than 0.5
# found better solution! using distance = 0.5 and start = 7.0
# 1000
# 0.5 is better than 0.5
# 6.0 is closest to 6.5

# %% [markdown]
# ## Demo: Application of Gradient Descent

# %%
lm = linear_model.SGDRegressor()
lm.fit(modeldata, y)
print "Gradient Descent R2:", lm.score(modeldata, y)
print "Gradient Descent MSE:", metrics.mean_squared_error(y, lm.predict(modeldata))
# Out:
# Gradient Descent R2: 0.307877801382
# Gradient Descent MSE: 1682.44257548

# %% [markdown]
# ### Check: Untuned, how well did gradient descent perform compared to OLS?

# %% [markdown]
# Answer: With lower R-squared and higher MSE, we can say that the performance of gradient descent is not as good as OLS.

# %% [markdown]
# # Independent Practice: Bike data revisited
#
# There are tons of ways to approach a regression problem. The regularization techniques appended to ordinary least squares optimizes the size of coefficients to best account for error. Gradient Descent also introduces learning rate (how aggressively do we solve the problem), epsilon (at what point do we say the error margin is acceptable), and iterations (when should we stop no matter what?)
#
# For this deliverable, our goals are to:
#
# - implement the gradient descent approach to our bike-share modeling problem,
# - show how gradient descent solves and optimizes the solution,
# - demonstrate the grid_search module!
#
# While exploring the Gradient Descent regressor object, you'll build a grid search using the stochastic gradient descent estimator for the bike-share data set. Continue with either the model you evaluated last class or the simpler one from today. In particular, be sure to implement the "param_grid" in the grid search to get answers for the following questions:
#
# - With a set of alpha values between 10^-10 and 10^-1, how does the mean squared error change?
# - Based on the data, we know when to properly use L1 vs L2 regularization. By using a grid search with L1_ratios between 0 and 1 (increasing every 0.05), does that statement hold true? If not, did gradient descent have enough iterations?
# - How do these results change when you alter the learning rate (eta0)?
#
# **Bonus**: Can you see the advantages and disadvantages of using gradient descent after finishing this exercise?

# %% [markdown]
# ### Starter Code

# %%
alphas = np.logspace(-10, -1, 10)
params = {'alpha': alphas} # put your gradient descent parameters here
print params
gs = grid_search.GridSearchCV(
    estimator=linear_model.SGDRegressor(n_iter=5),
    cv=cross_validation.KFold(len(modeldata), n_folds=5, shuffle=True),
    param_grid=params,
    scoring='neg_mean_squared_error',
    )

gs.fit(modeldata, y)

print 'BEST ESTIMATOR'
print -gs.best_score_
print gs.best_estimator_
print 'ALL ESTIMATORS'
for l2 in gs.grid_scores_:
    print l2
# Out:
# {'alpha': array([  1.00000000e-10,   1.00000000e-09,   1.00000000e-08,
#          1.00000000e-07,   1.00000000e-06,   1.00000000e-05,
#          1.00000000e-04,   1.00000000e-03,   1.00000000e-02,
#          1.00000000e-01])}
# BEST ESTIMATOR
# 1688.90980088
# SGDRegressor(alpha=9.9999999999999995e-08, average=False, epsilon=0.1,
#        eta0=0.01, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='invscaling', loss='squared_loss', n_iter=5,
#        penalty='l2', power_t=0.25, random_state=None, shuffle=True,
#        verbose=0, warm_start=False)
# ALL ESTIMATORS
# mean: -1688.95769, std: 98.23973, params: {'alpha': 1e-10}
# mean: -1691.59497, std: 94.02736, params: {'alpha': 1.0000000000000001e-09}
# mean: -1689.09775, std: 97.04417, params: {'alpha': 1e-08}
# mean: -1688.90980, std: 97.22039, params: {'alpha': 9.9999999999999995e-08}
# mean: -1689.35137, std: 97.42058, params: {'alpha': 9.9999999999999995e-07}
# mean: -1689.72196, std: 96.26277, params: {'alpha': 1.0000000000000001e-05}
# mean: -1691.12843, std: 95.96237, params: {'alpha': 0.0001}
# mean: -1692.66147, std: 100.32011, params: {'alpha': 0.001}
# mean: -1731.52962, std: 103.71057, params: {'alpha': 0.01}
# mean: -2053.49919, std: 121.56887, params: {'alpha': 0.10000000000000001}

# %%
alphas = np.logspace(-10, -1, 10)
params = {'alpha': alphas} # put your gradient descent parameters here
print params
gs = grid_search.GridSearchCV(
    estimator=linear_model.SGDRegressor(n_iter=50),
    cv=cross_validation.KFold(len(modeldata), n_folds=5, shuffle=True),
    param_grid=params,
    scoring='neg_mean_squared_error',
    )

gs.fit(modeldata, y)

print 'BEST ESTIMATOR'
print -gs.best_score_
print gs.best_estimator_
print 'ALL ESTIMATORS'
for l2 in gs.grid_scores_:
    print l2
# Out:
# {'alpha': array([  1.00000000e-10,   1.00000000e-09,   1.00000000e-08,
#          1.00000000e-07,   1.00000000e-06,   1.00000000e-05,
#          1.00000000e-04,   1.00000000e-03,   1.00000000e-02,
#          1.00000000e-01])}
# BEST ESTIMATOR
# 1673.4711707
# SGDRegressor(alpha=9.9999999999999995e-07, average=False, epsilon=0.1,
#        eta0=0.01, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='invscaling', loss='squared_loss', n_iter=50,
#        penalty='l2', power_t=0.25, random_state=None, shuffle=True,
#        verbose=0, warm_start=False)
# ALL ESTIMATORS
# mean: -1675.57559, std: 151.01367, params: {'alpha': 1e-10}
# mean: -1675.06859, std: 151.80016, params: {'alpha': 1.0000000000000001e-09}
# mean: -1675.21180, std: 152.57762, params: {'alpha': 1e-08}
# mean: -1674.02517, std: 151.99124, params: {'alpha': 9.9999999999999995e-08}
# mean: -1673.47117, std: 152.49810, params: {'alpha': 9.9999999999999995e-07}
# mean: -1674.05008, std: 152.09132, params: {'alpha': 1.0000000000000001e-05}
# mean: -1674.08452, std: 151.22571, params: {'alpha': 0.0001}
# mean: -1676.47706, std: 152.74172, params: {'alpha': 0.001}
# mean: -1708.50845, std: 167.43308, params: {'alpha': 0.01}
# mean: -2052.63224, std: 198.28130, params: {'alpha': 0.10000000000000001}

# %% [markdown]
# Conclusion: By only altering the alpha value and running the above code many times, we find that the MSE does not change much in between 1e-10 to 1e-4. The best estimator changes every time. MSE starts to rise when alpha is set beyond 1e-4. I also change the number of iterations in order to compare with the results below obtained from Lasso.

# %%
alphas = np.logspace(-10, -1, 10)
l1s = np.arange(0, 1, 0.05)
params = {'alpha': alphas, 'l1_ratio': l1s} # put your gradient descent parameters here
print params
gs = grid_search.GridSearchCV(
    estimator=linear_model.SGDRegressor(n_iter=5, penalty='l1'),
    cv=cross_validation.KFold(len(modeldata), n_folds=5, shuffle=True),
    param_grid=params,
    scoring='neg_mean_squared_error',
    )

gs.fit(modeldata, y)

print 'BEST ESTIMATOR'
print -gs.best_score_
print gs.best_estimator_
print 'ALL ESTIMATORS'
for l1 in gs.grid_scores_:
    print l1
# Out:
# {'alpha': array([  1.00000000e-10,   1.00000000e-09,   1.00000000e-08,
#          1.00000000e-07,   1.00000000e-06,   1.00000000e-05,
#          1.00000000e-04,   1.00000000e-03,   1.00000000e-02,
#          1.00000000e-01]), 'l1_ratio': array([ 0.  ,  0.05,  0.1 ,  0.15,  0.2 ,  0.25,  0.3 ,  0.35,  0.4 ,
#         0.45,  0.5 ,  0.55,  0.6 ,  0.65,  0.7 ,  0.75,  0.8 ,  0.85,
#         0.9 ,  0.95])}
# BEST ESTIMATOR
# 1688.07754617
# SGDRegressor(alpha=1.0000000000000001e-05, average=False, epsilon=0.1,
#        eta0=0.01, fit_intercept=True, l1_ratio=0.60000000000000009,
#        learning_rate='invscaling', loss='squared_loss', n_iter=5,
#        penalty='l1', power_t=0.25, random_state=None, shuffle=True,
#        verbose=0, warm_start=False)
# ALL ESTIMATORS
# mean: -1688.99274, std: 83.46992, params: {'alpha': 1e-10, 'l1_ratio': 0.0}
# mean: -1689.54038, std: 84.92972, params: {'alpha': 1e-10, 'l1_ratio': 0.050000000000000003}
# mean: -1688.71744, std: 84.29532, params: {'alpha': 1e-10, 'l1_ratio': 0.10000000000000001}
# mean: -1689.72621, std: 86.02196, params: {'alpha': 1e-10, 'l1_ratio': 0.15000000000000002}
# mean: -1688.79223, std: 85.32270, params: {'alpha': 1e-10, 'l1_ratio': 0.20000000000000001}
# mean: -1688.43367, std: 84.26129, params: {'alpha': 1e-10, 'l1_ratio': 0.25}
# mean: -1688.45964, std: 83.80697, params: {'alpha': 1e-10, 'l1_ratio': 0.30000000000000004}
# mean: -1689.25467, std: 84.37861, params: {'alpha': 1e-10, 'l1_ratio': 0.35000000000000003}
# mean: -1688.45719, std: 84.33401, params: {'alpha': 1e-10, 'l1_ratio': 0.40000000000000002}
# mean: -1689.74579, std: 84.16976, params: {'alpha': 1e-10, 'l1_ratio': 0.45000000000000001}
# mean: -1690.61786, std: 85.49865, params: {'alpha': 1e-10, 'l1_ratio': 0.5}
# mean: -1689.47941, std: 84.02641, params: {'alpha': 1e-10, 'l1_ratio': 0.55000000000000004}
# mean: -1688.35870, std: 84.86156, params: {'alpha': 1e-10, 'l1_ratio': 0.60000000000000009}
# mean: -1689.50033, std: 84.96661, params: {'alpha': 1e-10, 'l1_ratio': 0.65000000000000002}
# mean: -1688.18835, std: 84.16021, params: {'alpha': 1e-10, 'l1_ratio': 0.70000000000000007}
# mean: -1690.16835, std: 84.06561, params: {'alpha': 1e-10, 'l1_ratio': 0.75}
# mean: -1689.03466, std: 84.52371, params: {'alpha': 1e-10, 'l1_ratio': 0.80000000000000004}
# mean: -1690.20140, std: 84.18523, params: {'alpha': 1e-10, 'l1_ratio': 0.85000000000000009}
# mean: -1689.59500, std: 84.69476, params: {'alpha': 1e-10, 'l1_ratio': 0.90000000000000002}
# mean: -1691.42004, std: 83.04912, params: {'alpha': 1e-10, 'l1_ratio': 0.95000000000000007}
# mean: -1688.98024, std: 84.69605, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.0}
# mean: -1689.28781, std: 84.30433, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.050000000000000003}
# mean: -1688.72515, std: 84.62297, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.10000000000000001}
# mean: -1690.42850, std: 84.16643, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.15000000000000002}
# mean: -1690.01788, std: 83.37092, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.20000000000000001}
# mean: -1690.52422, std: 87.31033, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.25}
# mean: -1690.43390, std: 84.60351, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.30000000000000004}
# mean: -1688.48107, std: 84.29173, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.35000000000000003}
# mean: -1689.90825, std: 84.36055, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.40000000000000002}
# mean: -1688.59396, std: 83.99517, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.45000000000000001}
# mean: -1692.10529, std: 84.09996, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.5}
# mean: -1688.85268, std: 84.88058, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.55000000000000004}
# mean: -1689.14242, std: 83.48650, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.60000000000000009}
# mean: -1688.70291, std: 84.34366, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.65000000000000002}
# mean: -1688.84054, std: 83.94250, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.70000000000000007}
# mean: -1691.02501, std: 84.84089, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.75}
# mean: -1689.52135, std: 85.68662, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.80000000000000004}
# mean: -1689.35065, std: 85.08267, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.85000000000000009}
# mean: -1688.69137, std: 84.45638, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.90000000000000002}
# mean: -1690.86968, std: 87.07054, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.95000000000000007}
# mean: -1688.64134, std: 84.50706, params: {'alpha': 1e-08, 'l1_ratio': 0.0}
# mean: -1688.44453, std: 84.34393, params: {'alpha': 1e-08, 'l1_ratio': 0.050000000000000003}
# mean: -1689.14604, std: 85.26292, params: {'alpha': 1e-08, 'l1_ratio': 0.10000000000000001}
# mean: -1689.34458, std: 84.46150, params: {'alpha': 1e-08, 'l1_ratio': 0.15000000000000002}
# mean: -1690.50548, std: 83.10328, params: {'alpha': 1e-08, 'l1_ratio': 0.20000000000000001}
# mean: -1688.69303, std: 84.44307, params: {'alpha': 1e-08, 'l1_ratio': 0.25}
# mean: -1689.40098, std: 83.51122, params: {'alpha': 1e-08, 'l1_ratio': 0.30000000000000004}
# mean: -1688.79758, std: 84.02024, params: {'alpha': 1e-08, 'l1_ratio': 0.35000000000000003}
# mean: -1688.53346, std: 84.50911, params: {'alpha': 1e-08, 'l1_ratio': 0.40000000000000002}
# mean: -1689.30769, std: 84.16671, params: {'alpha': 1e-08, 'l1_ratio': 0.45000000000000001}
# mean: -1692.21340, std: 82.56553, params: {'alpha': 1e-08, 'l1_ratio': 0.5}
# mean: -1688.96614, std: 84.41428, params: {'alpha': 1e-08, 'l1_ratio': 0.55000000000000004}
# mean: -1688.87540, std: 83.75321, params: {'alpha': 1e-08, 'l1_ratio': 0.60000000000000009}
# mean: -1689.39527, std: 85.51390, params: {'alpha': 1e-08, 'l1_ratio': 0.65000000000000002}
# mean: -1690.68310, std: 84.72601, params: {'alpha': 1e-08, 'l1_ratio': 0.70000000000000007}
# mean: -1689.35887, std: 84.50158, params: {'alpha': 1e-08, 'l1_ratio': 0.75}
# mean: -1689.39393, std: 84.23577, params: {'alpha': 1e-08, 'l1_ratio': 0.80000000000000004}
# mean: -1693.23294, std: 84.53806, params: {'alpha': 1e-08, 'l1_ratio': 0.85000000000000009}
# mean: -1688.72988, std: 85.05643, params: {'alpha': 1e-08, 'l1_ratio': 0.90000000000000002}
# mean: -1688.68239, std: 84.65233, params: {'alpha': 1e-08, 'l1_ratio': 0.95000000000000007}
# mean: -1689.12757, std: 83.52643, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.0}
# mean: -1689.11849, std: 84.15635, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.050000000000000003}
# mean: -1689.36525, std: 84.78770, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.10000000000000001}
# mean: -1688.95427, std: 84.42392, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.15000000000000002}
# mean: -1689.55040, std: 85.20162, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.20000000000000001}
# mean: -1688.99990, std: 85.43126, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.25}
# mean: -1688.64919, std: 84.79987, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.30000000000000004}
# mean: -1688.90458, std: 84.40370, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.35000000000000003}
# mean: -1689.14073, std: 84.00326, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.40000000000000002}
# mean: -1690.65241, std: 83.76478, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.45000000000000001}
# mean: -1689.71901, std: 84.38745, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.5}
# mean: -1689.90281, std: 82.68647, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.55000000000000004}
# mean: -1688.70311, std: 83.66710, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.60000000000000009}
# mean: -1693.14070, std: 82.17307, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.65000000000000002}
# mean: -1690.85729, std: 82.14398, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.70000000000000007}
# mean: -1688.79197, std: 85.14803, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.75}
# mean: -1688.93032, std: 83.66096, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.80000000000000004}
# mean: -1688.75461, std: 84.37602, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.85000000000000009}
# mean: -1691.31147, std: 82.26880, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.90000000000000002}
# mean: -1692.56536, std: 83.36551, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.95000000000000007}
# mean: -1689.27486, std: 84.33248, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.0}
# mean: -1688.65033, std: 84.07938, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.050000000000000003}
# mean: -1689.72209, std: 82.93630, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.10000000000000001}
# mean: -1691.23345, std: 83.73123, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.15000000000000002}
# mean: -1688.77435, std: 84.02356, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.20000000000000001}
# mean: -1689.03110, std: 83.78786, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.25}
# mean: -1688.68631, std: 84.05257, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.30000000000000004}
# mean: -1690.12298, std: 83.35096, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.35000000000000003}
# mean: -1690.48147, std: 86.67192, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.40000000000000002}
# mean: -1689.26280, std: 84.15560, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.45000000000000001}
# mean: -1689.20255, std: 84.40652, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.5}
# mean: -1691.85090, std: 84.39240, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.55000000000000004}
# mean: -1691.38049, std: 87.03224, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.60000000000000009}
# mean: -1689.14893, std: 84.85446, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.65000000000000002}
# mean: -1691.10138, std: 82.81977, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.70000000000000007}
# mean: -1691.40203, std: 81.23338, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.75}
# mean: -1688.94148, std: 84.49586, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.80000000000000004}
# mean: -1688.89793, std: 83.76366, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.85000000000000009}
# mean: -1689.35480, std: 83.66453, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.90000000000000002}
# mean: -1689.01861, std: 85.65358, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.95000000000000007}
# mean: -1689.40629, std: 83.42416, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.0}
# mean: -1689.15903, std: 83.64864, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.050000000000000003}
# mean: -1688.95416, std: 84.15283, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.10000000000000001}
# mean: -1688.95435, std: 83.96650, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.15000000000000002}
# mean: -1689.47475, std: 84.44388, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.20000000000000001}
# mean: -1689.28949, std: 84.26822, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.25}
# mean: -1690.45337, std: 82.10436, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.30000000000000004}
# mean: -1688.95791, std: 84.24772, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.35000000000000003}
# mean: -1693.04497, std: 88.98495, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.40000000000000002}
# mean: -1688.24298, std: 84.34990, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.45000000000000001}
# mean: -1688.58674, std: 83.89140, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.5}
# mean: -1689.73920, std: 84.37861, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.55000000000000004}
# mean: -1688.07755, std: 84.26049, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.60000000000000009}
# mean: -1689.23375, std: 85.12393, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.65000000000000002}
# mean: -1689.29898, std: 83.30569, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.70000000000000007}
# mean: -1689.69552, std: 83.31210, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.75}
# mean: -1692.01056, std: 81.24786, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.80000000000000004}
# mean: -1690.23990, std: 84.69898, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.85000000000000009}
# mean: -1689.84597, std: 84.32918, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.90000000000000002}
# mean: -1688.46089, std: 85.62866, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.95000000000000007}
# mean: -1690.27276, std: 84.44363, params: {'alpha': 0.0001, 'l1_ratio': 0.0}
# mean: -1688.44473, std: 84.43180, params: {'alpha': 0.0001, 'l1_ratio': 0.050000000000000003}
# mean: -1689.23474, std: 83.92645, params: {'alpha': 0.0001, 'l1_ratio': 0.10000000000000001}
# mean: -1689.53152, std: 85.42914, params: {'alpha': 0.0001, 'l1_ratio': 0.15000000000000002}
# mean: -1690.45024, std: 83.57572, params: {'alpha': 0.0001, 'l1_ratio': 0.20000000000000001}
# mean: -1689.81340, std: 84.68425, params: {'alpha': 0.0001, 'l1_ratio': 0.25}
# mean: -1689.24356, std: 85.83447, params: {'alpha': 0.0001, 'l1_ratio': 0.30000000000000004}
# mean: -1690.10750, std: 84.79670, params: {'alpha': 0.0001, 'l1_ratio': 0.35000000000000003}
# mean: -1689.54753, std: 84.41840, params: {'alpha': 0.0001, 'l1_ratio': 0.40000000000000002}
# mean: -1691.20812, std: 84.46120, params: {'alpha': 0.0001, 'l1_ratio': 0.45000000000000001}
# mean: -1689.93206, std: 83.81167, params: {'alpha': 0.0001, 'l1_ratio': 0.5}
# mean: -1689.29869, std: 85.58951, params: {'alpha': 0.0001, 'l1_ratio': 0.55000000000000004}
# mean: -1690.06165, std: 85.66586, params: {'alpha': 0.0001, 'l1_ratio': 0.60000000000000009}
# mean: -1690.27153, std: 85.77124, params: {'alpha': 0.0001, 'l1_ratio': 0.65000000000000002}
# mean: -1688.47027, std: 84.57312, params: {'alpha': 0.0001, 'l1_ratio': 0.70000000000000007}
# mean: -1689.65789, std: 84.58186, params: {'alpha': 0.0001, 'l1_ratio': 0.75}
# mean: -1689.68519, std: 83.17094, params: {'alpha': 0.0001, 'l1_ratio': 0.80000000000000004}
# mean: -1690.06589, std: 84.30252, params: {'alpha': 0.0001, 'l1_ratio': 0.85000000000000009}
# mean: -1688.87428, std: 84.76349, params: {'alpha': 0.0001, 'l1_ratio': 0.90000000000000002}
# mean: -1688.60417, std: 84.09713, params: {'alpha': 0.0001, 'l1_ratio': 0.95000000000000007}
# mean: -1688.29935, std: 84.24055, params: {'alpha': 0.001, 'l1_ratio': 0.0}
# mean: -1689.05817, std: 84.32184, params: {'alpha': 0.001, 'l1_ratio': 0.050000000000000003}
# mean: -1689.57041, std: 82.96337, params: {'alpha': 0.001, 'l1_ratio': 0.10000000000000001}
# mean: -1689.66214, std: 84.45016, params: {'alpha': 0.001, 'l1_ratio': 0.15000000000000002}
# mean: -1689.34010, std: 83.99454, params: {'alpha': 0.001, 'l1_ratio': 0.20000000000000001}
# mean: -1691.17521, std: 85.13062, params: {'alpha': 0.001, 'l1_ratio': 0.25}
# mean: -1688.90221, std: 84.45864, params: {'alpha': 0.001, 'l1_ratio': 0.30000000000000004}
# mean: -1690.94891, std: 87.32483, params: {'alpha': 0.001, 'l1_ratio': 0.35000000000000003}
# mean: -1688.25763, std: 84.46967, params: {'alpha': 0.001, 'l1_ratio': 0.40000000000000002}
# mean: -1689.85154, std: 85.52955, params: {'alpha': 0.001, 'l1_ratio': 0.45000000000000001}
# mean: -1689.44927, std: 85.73812, params: {'alpha': 0.001, 'l1_ratio': 0.5}
# mean: -1688.54215, std: 84.28589, params: {'alpha': 0.001, 'l1_ratio': 0.55000000000000004}
# mean: -1689.59108, std: 84.43991, params: {'alpha': 0.001, 'l1_ratio': 0.60000000000000009}
# mean: -1689.10306, std: 83.70199, params: {'alpha': 0.001, 'l1_ratio': 0.65000000000000002}
# mean: -1689.93293, std: 82.75474, params: {'alpha': 0.001, 'l1_ratio': 0.70000000000000007}
# mean: -1688.70929, std: 84.65308, params: {'alpha': 0.001, 'l1_ratio': 0.75}
# mean: -1688.75062, std: 84.42588, params: {'alpha': 0.001, 'l1_ratio': 0.80000000000000004}
# mean: -1690.93208, std: 83.34952, params: {'alpha': 0.001, 'l1_ratio': 0.85000000000000009}
# mean: -1690.36783, std: 83.16919, params: {'alpha': 0.001, 'l1_ratio': 0.90000000000000002}
# mean: -1689.46501, std: 83.95580, params: {'alpha': 0.001, 'l1_ratio': 0.95000000000000007}
# mean: -1689.75293, std: 83.63696, params: {'alpha': 0.01, 'l1_ratio': 0.0}
# mean: -1689.60019, std: 84.64814, params: {'alpha': 0.01, 'l1_ratio': 0.050000000000000003}
# mean: -1690.16507, std: 84.22918, params: {'alpha': 0.01, 'l1_ratio': 0.10000000000000001}
# mean: -1688.95669, std: 84.39446, params: {'alpha': 0.01, 'l1_ratio': 0.15000000000000002}
# mean: -1691.46837, std: 83.50243, params: {'alpha': 0.01, 'l1_ratio': 0.20000000000000001}
# mean: -1690.60442, std: 84.08968, params: {'alpha': 0.01, 'l1_ratio': 0.25}
# mean: -1690.22774, std: 85.30332, params: {'alpha': 0.01, 'l1_ratio': 0.30000000000000004}
# mean: -1689.43532, std: 84.70054, params: {'alpha': 0.01, 'l1_ratio': 0.35000000000000003}
# mean: -1689.19852, std: 84.70676, params: {'alpha': 0.01, 'l1_ratio': 0.40000000000000002}
# mean: -1691.61531, std: 83.41144, params: {'alpha': 0.01, 'l1_ratio': 0.45000000000000001}
# mean: -1690.02891, std: 84.20209, params: {'alpha': 0.01, 'l1_ratio': 0.5}
# mean: -1689.49233, std: 83.88374, params: {'alpha': 0.01, 'l1_ratio': 0.55000000000000004}
# mean: -1689.35260, std: 84.36826, params: {'alpha': 0.01, 'l1_ratio': 0.60000000000000009}
# mean: -1688.86174, std: 84.49206, params: {'alpha': 0.01, 'l1_ratio': 0.65000000000000002}
# mean: -1690.07415, std: 85.84130, params: {'alpha': 0.01, 'l1_ratio': 0.70000000000000007}
# mean: -1691.06539, std: 84.38721, params: {'alpha': 0.01, 'l1_ratio': 0.75}
# mean: -1689.40351, std: 85.30830, params: {'alpha': 0.01, 'l1_ratio': 0.80000000000000004}
# mean: -1689.78024, std: 84.06406, params: {'alpha': 0.01, 'l1_ratio': 0.85000000000000009}
# mean: -1690.17605, std: 83.45890, params: {'alpha': 0.01, 'l1_ratio': 0.90000000000000002}
# mean: -1691.77780, std: 83.48001, params: {'alpha': 0.01, 'l1_ratio': 0.95000000000000007}
# mean: -1694.61500, std: 83.98051, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.0}
# mean: -1697.90172, std: 88.41645, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.050000000000000003}
# mean: -1695.42875, std: 85.62374, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.10000000000000001}
# mean: -1695.48697, std: 85.37219, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.15000000000000002}
# mean: -1695.39105, std: 84.18200, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.20000000000000001}
# mean: -1694.63395, std: 85.48773, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.25}
# mean: -1694.46999, std: 84.66239, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.30000000000000004}
# mean: -1694.60695, std: 84.73633, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.35000000000000003}
# mean: -1695.22088, std: 84.83704, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.40000000000000002}
# mean: -1694.44634, std: 84.61766, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.45000000000000001}
# mean: -1694.16729, std: 85.57458, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.5}
# mean: -1698.24118, std: 83.91565, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.55000000000000004}
# mean: -1694.88075, std: 84.17565, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.60000000000000009}
# mean: -1694.57312, std: 84.33828, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.65000000000000002}
# mean: -1697.45043, std: 83.53951, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.70000000000000007}
# mean: -1694.53249, std: 85.56489, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.75}
# mean: -1695.58289, std: 85.19634, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.80000000000000004}
# mean: -1693.71782, std: 85.06816, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.85000000000000009}
# mean: -1694.29740, std: 85.67305, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.90000000000000002}
# mean: -1695.07621, std: 83.50597, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.95000000000000007}

# %%
alphas = np.logspace(-10, -1, 10)
l1s = np.arange(0, 1, 0.05)
params = {'alpha': alphas, 'l1_ratio': l1s} # put your gradient descent parameters here
print params
gs = grid_search.GridSearchCV(
    estimator=linear_model.SGDRegressor(n_iter=50, penalty='l1'),
    cv=cross_validation.KFold(len(modeldata), n_folds=5, shuffle=True),
    param_grid=params,
    scoring='neg_mean_squared_error',
    )

gs.fit(modeldata, y)

print 'BEST ESTIMATOR'
print -gs.best_score_
print gs.best_estimator_
print 'ALL ESTIMATORS'
for l1 in gs.grid_scores_:
    print l1
# Out:
# {'alpha': array([  1.00000000e-10,   1.00000000e-09,   1.00000000e-08,
#          1.00000000e-07,   1.00000000e-06,   1.00000000e-05,
#          1.00000000e-04,   1.00000000e-03,   1.00000000e-02,
#          1.00000000e-01]), 'l1_ratio': array([ 0.  ,  0.05,  0.1 ,  0.15,  0.2 ,  0.25,  0.3 ,  0.35,  0.4 ,
#         0.45,  0.5 ,  0.55,  0.6 ,  0.65,  0.7 ,  0.75,  0.8 ,  0.85,
#         0.9 ,  0.95])}
# BEST ESTIMATOR
# 1673.42952178
# SGDRegressor(alpha=1.0000000000000001e-09, average=False, epsilon=0.1,
#        eta0=0.01, fit_intercept=True, l1_ratio=0.050000000000000003,
#        learning_rate='invscaling', loss='squared_loss', n_iter=50,
#        penalty='l1', power_t=0.25, random_state=None, shuffle=True,
#        verbose=0, warm_start=False)
# ALL ESTIMATORS
# mean: -1674.41568, std: 75.62859, params: {'alpha': 1e-10, 'l1_ratio': 0.0}
# mean: -1673.91789, std: 75.60558, params: {'alpha': 1e-10, 'l1_ratio': 0.050000000000000003}
# mean: -1673.61311, std: 75.47651, params: {'alpha': 1e-10, 'l1_ratio': 0.10000000000000001}
# mean: -1674.59770, std: 75.10947, params: {'alpha': 1e-10, 'l1_ratio': 0.15000000000000002}
# mean: -1673.56390, std: 75.75413, params: {'alpha': 1e-10, 'l1_ratio': 0.20000000000000001}
# mean: -1675.60709, std: 74.11103, params: {'alpha': 1e-10, 'l1_ratio': 0.25}
# mean: -1674.09059, std: 75.19875, params: {'alpha': 1e-10, 'l1_ratio': 0.30000000000000004}
# mean: -1674.52381, std: 76.15239, params: {'alpha': 1e-10, 'l1_ratio': 0.35000000000000003}
# mean: -1673.91684, std: 75.53971, params: {'alpha': 1e-10, 'l1_ratio': 0.40000000000000002}
# mean: -1674.50639, std: 75.20362, params: {'alpha': 1e-10, 'l1_ratio': 0.45000000000000001}
# mean: -1673.57183, std: 75.41206, params: {'alpha': 1e-10, 'l1_ratio': 0.5}
# mean: -1674.86927, std: 75.48101, params: {'alpha': 1e-10, 'l1_ratio': 0.55000000000000004}
# mean: -1673.87095, std: 75.79680, params: {'alpha': 1e-10, 'l1_ratio': 0.60000000000000009}
# mean: -1674.46936, std: 75.96998, params: {'alpha': 1e-10, 'l1_ratio': 0.65000000000000002}
# mean: -1673.91817, std: 74.80219, params: {'alpha': 1e-10, 'l1_ratio': 0.70000000000000007}
# mean: -1673.94213, std: 74.60762, params: {'alpha': 1e-10, 'l1_ratio': 0.75}
# mean: -1675.54294, std: 73.75697, params: {'alpha': 1e-10, 'l1_ratio': 0.80000000000000004}
# mean: -1674.53113, std: 75.14208, params: {'alpha': 1e-10, 'l1_ratio': 0.85000000000000009}
# mean: -1676.04502, std: 76.69303, params: {'alpha': 1e-10, 'l1_ratio': 0.90000000000000002}
# mean: -1674.22740, std: 75.66091, params: {'alpha': 1e-10, 'l1_ratio': 0.95000000000000007}
# mean: -1674.29290, std: 73.94274, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.0}
# mean: -1673.42952, std: 75.39850, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.050000000000000003}
# mean: -1673.76139, std: 75.25727, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.10000000000000001}
# mean: -1675.55712, std: 75.77787, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.15000000000000002}
# mean: -1673.78014, std: 75.65368, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.20000000000000001}
# mean: -1674.24069, std: 74.03725, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.25}
# mean: -1674.55943, std: 74.83246, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.30000000000000004}
# mean: -1674.17289, std: 75.06840, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.35000000000000003}
# mean: -1673.60491, std: 75.13620, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.40000000000000002}
# mean: -1673.71827, std: 75.66319, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.45000000000000001}
# mean: -1674.67741, std: 75.29197, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.5}
# mean: -1674.83033, std: 76.53729, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.55000000000000004}
# mean: -1673.90256, std: 75.51879, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.60000000000000009}
# mean: -1674.71117, std: 76.15734, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.65000000000000002}
# mean: -1674.22471, std: 74.66951, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.70000000000000007}
# mean: -1675.42917, std: 74.49646, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.75}
# mean: -1674.69257, std: 76.14962, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.80000000000000004}
# mean: -1673.90912, std: 75.70064, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.85000000000000009}
# mean: -1674.39046, std: 75.57522, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.90000000000000002}
# mean: -1674.57607, std: 74.60839, params: {'alpha': 1.0000000000000001e-09, 'l1_ratio': 0.95000000000000007}
# mean: -1674.88654, std: 75.83556, params: {'alpha': 1e-08, 'l1_ratio': 0.0}
# mean: -1673.56849, std: 75.59500, params: {'alpha': 1e-08, 'l1_ratio': 0.050000000000000003}
# mean: -1675.20978, std: 76.93069, params: {'alpha': 1e-08, 'l1_ratio': 0.10000000000000001}
# mean: -1674.60647, std: 74.72514, params: {'alpha': 1e-08, 'l1_ratio': 0.15000000000000002}
# mean: -1674.12482, std: 75.56020, params: {'alpha': 1e-08, 'l1_ratio': 0.20000000000000001}
# mean: -1673.75086, std: 75.14882, params: {'alpha': 1e-08, 'l1_ratio': 0.25}
# mean: -1674.23113, std: 76.03509, params: {'alpha': 1e-08, 'l1_ratio': 0.30000000000000004}
# mean: -1675.15434, std: 74.56263, params: {'alpha': 1e-08, 'l1_ratio': 0.35000000000000003}
# mean: -1675.08753, std: 76.45768, params: {'alpha': 1e-08, 'l1_ratio': 0.40000000000000002}
# mean: -1673.97187, std: 75.09984, params: {'alpha': 1e-08, 'l1_ratio': 0.45000000000000001}
# mean: -1675.26644, std: 72.51170, params: {'alpha': 1e-08, 'l1_ratio': 0.5}
# mean: -1674.20535, std: 74.88225, params: {'alpha': 1e-08, 'l1_ratio': 0.55000000000000004}
# mean: -1674.11435, std: 75.47010, params: {'alpha': 1e-08, 'l1_ratio': 0.60000000000000009}
# mean: -1674.12051, std: 75.66996, params: {'alpha': 1e-08, 'l1_ratio': 0.65000000000000002}
# mean: -1675.13297, std: 73.89423, params: {'alpha': 1e-08, 'l1_ratio': 0.70000000000000007}
# mean: -1674.56457, std: 74.18437, params: {'alpha': 1e-08, 'l1_ratio': 0.75}
# mean: -1676.33030, std: 78.79481, params: {'alpha': 1e-08, 'l1_ratio': 0.80000000000000004}
# mean: -1675.70042, std: 74.87893, params: {'alpha': 1e-08, 'l1_ratio': 0.85000000000000009}
# mean: -1674.51423, std: 74.22197, params: {'alpha': 1e-08, 'l1_ratio': 0.90000000000000002}
# mean: -1674.66466, std: 74.61130, params: {'alpha': 1e-08, 'l1_ratio': 0.95000000000000007}
# mean: -1673.59446, std: 75.47402, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.0}
# mean: -1674.84733, std: 73.73682, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.050000000000000003}
# mean: -1674.44223, std: 75.09662, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.10000000000000001}
# mean: -1673.86629, std: 75.44246, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.15000000000000002}
# mean: -1675.55071, std: 75.66436, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.20000000000000001}
# mean: -1674.69533, std: 74.61966, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.25}
# mean: -1674.28427, std: 75.60804, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.30000000000000004}
# mean: -1673.85891, std: 75.90935, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.35000000000000003}
# mean: -1674.59486, std: 75.48304, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.40000000000000002}
# mean: -1674.99520, std: 76.53907, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.45000000000000001}
# mean: -1675.21115, std: 74.01845, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.5}
# mean: -1673.58374, std: 75.31121, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.55000000000000004}
# mean: -1675.15239, std: 74.92010, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.60000000000000009}
# mean: -1674.22453, std: 75.76034, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.65000000000000002}
# mean: -1673.92563, std: 75.55213, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.70000000000000007}
# mean: -1675.20188, std: 75.10971, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.75}
# mean: -1673.93321, std: 75.44870, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.80000000000000004}
# mean: -1674.08105, std: 75.07650, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.85000000000000009}
# mean: -1674.41159, std: 76.28574, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.90000000000000002}
# mean: -1674.14885, std: 76.09845, params: {'alpha': 9.9999999999999995e-08, 'l1_ratio': 0.95000000000000007}
# mean: -1676.45355, std: 72.40014, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.0}
# mean: -1674.46568, std: 76.08854, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.050000000000000003}
# mean: -1674.68822, std: 76.40956, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.10000000000000001}
# mean: -1674.00172, std: 75.63598, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.15000000000000002}
# mean: -1674.53726, std: 75.90477, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.20000000000000001}
# mean: -1673.78750, std: 75.46405, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.25}
# mean: -1675.22224, std: 74.55609, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.30000000000000004}
# mean: -1673.73699, std: 75.45974, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.35000000000000003}
# mean: -1674.28574, std: 75.76006, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.40000000000000002}
# mean: -1674.75019, std: 74.74759, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.45000000000000001}
# mean: -1674.03829, std: 74.95401, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.5}
# mean: -1674.91805, std: 75.16747, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.55000000000000004}
# mean: -1675.73569, std: 76.55773, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.60000000000000009}
# mean: -1673.69641, std: 74.97345, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.65000000000000002}
# mean: -1674.24106, std: 75.88099, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.70000000000000007}
# mean: -1675.34524, std: 76.32261, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.75}
# mean: -1675.84315, std: 72.67620, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.80000000000000004}
# mean: -1674.03842, std: 75.74156, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.85000000000000009}
# mean: -1674.82888, std: 74.96087, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.90000000000000002}
# mean: -1673.63702, std: 75.23863, params: {'alpha': 9.9999999999999995e-07, 'l1_ratio': 0.95000000000000007}
# mean: -1674.04484, std: 74.83677, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.0}
# mean: -1674.74668, std: 75.56129, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.050000000000000003}
# mean: -1675.38404, std: 75.24953, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.10000000000000001}
# mean: -1675.26645, std: 76.01277, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.15000000000000002}
# mean: -1673.66887, std: 75.39457, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.20000000000000001}
# mean: -1675.19743, std: 73.47032, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.25}
# mean: -1674.51535, std: 76.27648, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.30000000000000004}
# mean: -1674.38036, std: 75.59598, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.35000000000000003}
# mean: -1673.93864, std: 74.92523, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.40000000000000002}
# mean: -1674.37968, std: 75.37081, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.45000000000000001}
# mean: -1674.09488, std: 76.33701, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.5}
# mean: -1674.90627, std: 75.80552, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.55000000000000004}
# mean: -1674.08633, std: 74.32380, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.60000000000000009}
# mean: -1674.35048, std: 75.49441, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.65000000000000002}
# mean: -1674.39491, std: 74.89846, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.70000000000000007}
# mean: -1675.32623, std: 77.06054, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.75}
# mean: -1674.25449, std: 75.43822, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.80000000000000004}
# mean: -1674.52268, std: 73.35576, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.85000000000000009}
# mean: -1674.56522, std: 75.91964, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.90000000000000002}
# mean: -1674.12835, std: 74.74602, params: {'alpha': 1.0000000000000001e-05, 'l1_ratio': 0.95000000000000007}
# mean: -1674.05864, std: 75.12364, params: {'alpha': 0.0001, 'l1_ratio': 0.0}
# mean: -1674.79658, std: 74.66487, params: {'alpha': 0.0001, 'l1_ratio': 0.050000000000000003}
# mean: -1674.49315, std: 75.31515, params: {'alpha': 0.0001, 'l1_ratio': 0.10000000000000001}
# mean: -1673.89706, std: 75.56131, params: {'alpha': 0.0001, 'l1_ratio': 0.15000000000000002}
# mean: -1674.29981, std: 75.44171, params: {'alpha': 0.0001, 'l1_ratio': 0.20000000000000001}
# mean: -1674.88327, std: 76.20816, params: {'alpha': 0.0001, 'l1_ratio': 0.25}
# mean: -1673.55493, std: 75.32165, params: {'alpha': 0.0001, 'l1_ratio': 0.30000000000000004}
# mean: -1674.08804, std: 75.16175, params: {'alpha': 0.0001, 'l1_ratio': 0.35000000000000003}
# mean: -1673.79009, std: 75.76657, params: {'alpha': 0.0001, 'l1_ratio': 0.40000000000000002}
# mean: -1673.93310, std: 75.71868, params: {'alpha': 0.0001, 'l1_ratio': 0.45000000000000001}
# mean: -1674.41266, std: 75.30043, params: {'alpha': 0.0001, 'l1_ratio': 0.5}
# mean: -1674.06186, std: 76.01478, params: {'alpha': 0.0001, 'l1_ratio': 0.55000000000000004}
# mean: -1673.91338, std: 75.37390, params: {'alpha': 0.0001, 'l1_ratio': 0.60000000000000009}
# mean: -1676.15107, std: 77.27980, params: {'alpha': 0.0001, 'l1_ratio': 0.65000000000000002}
# mean: -1674.62671, std: 74.92198, params: {'alpha': 0.0001, 'l1_ratio': 0.70000000000000007}
# mean: -1674.13824, std: 75.22850, params: {'alpha': 0.0001, 'l1_ratio': 0.75}
# mean: -1674.42828, std: 75.83068, params: {'alpha': 0.0001, 'l1_ratio': 0.80000000000000004}
# mean: -1675.48399, std: 77.09717, params: {'alpha': 0.0001, 'l1_ratio': 0.85000000000000009}
# mean: -1673.93470, std: 75.89101, params: {'alpha': 0.0001, 'l1_ratio': 0.90000000000000002}
# mean: -1674.53731, std: 76.33619, params: {'alpha': 0.0001, 'l1_ratio': 0.95000000000000007}
# mean: -1675.30100, std: 76.34837, params: {'alpha': 0.001, 'l1_ratio': 0.0}
# mean: -1674.52867, std: 75.65390, params: {'alpha': 0.001, 'l1_ratio': 0.050000000000000003}
# mean: -1674.46746, std: 74.85403, params: {'alpha': 0.001, 'l1_ratio': 0.10000000000000001}
# mean: -1674.79982, std: 75.03079, params: {'alpha': 0.001, 'l1_ratio': 0.15000000000000002}
# mean: -1674.58020, std: 75.48033, params: {'alpha': 0.001, 'l1_ratio': 0.20000000000000001}
# mean: -1675.16513, std: 75.31974, params: {'alpha': 0.001, 'l1_ratio': 0.25}
# mean: -1674.38657, std: 76.36480, params: {'alpha': 0.001, 'l1_ratio': 0.30000000000000004}
# mean: -1674.86628, std: 74.56483, params: {'alpha': 0.001, 'l1_ratio': 0.35000000000000003}
# mean: -1675.13061, std: 75.73199, params: {'alpha': 0.001, 'l1_ratio': 0.40000000000000002}
# mean: -1673.81988, std: 75.32795, params: {'alpha': 0.001, 'l1_ratio': 0.45000000000000001}
# mean: -1674.19506, std: 76.17158, params: {'alpha': 0.001, 'l1_ratio': 0.5}
# mean: -1674.74500, std: 75.46218, params: {'alpha': 0.001, 'l1_ratio': 0.55000000000000004}
# mean: -1673.99195, std: 74.96297, params: {'alpha': 0.001, 'l1_ratio': 0.60000000000000009}
# mean: -1674.86331, std: 76.15265, params: {'alpha': 0.001, 'l1_ratio': 0.65000000000000002}
# mean: -1674.20002, std: 75.43884, params: {'alpha': 0.001, 'l1_ratio': 0.70000000000000007}
# mean: -1674.14242, std: 75.09584, params: {'alpha': 0.001, 'l1_ratio': 0.75}
# mean: -1674.19767, std: 75.70338, params: {'alpha': 0.001, 'l1_ratio': 0.80000000000000004}
# mean: -1674.62614, std: 75.17724, params: {'alpha': 0.001, 'l1_ratio': 0.85000000000000009}
# mean: -1674.02716, std: 75.70015, params: {'alpha': 0.001, 'l1_ratio': 0.90000000000000002}
# mean: -1674.09035, std: 75.69742, params: {'alpha': 0.001, 'l1_ratio': 0.95000000000000007}
# mean: -1674.32126, std: 74.89819, params: {'alpha': 0.01, 'l1_ratio': 0.0}
# mean: -1674.50420, std: 74.73566, params: {'alpha': 0.01, 'l1_ratio': 0.050000000000000003}
# mean: -1674.28878, std: 75.57367, params: {'alpha': 0.01, 'l1_ratio': 0.10000000000000001}
# mean: -1673.93019, std: 74.49674, params: {'alpha': 0.01, 'l1_ratio': 0.15000000000000002}
# mean: -1675.10545, std: 76.17832, params: {'alpha': 0.01, 'l1_ratio': 0.20000000000000001}
# mean: -1674.70812, std: 75.07961, params: {'alpha': 0.01, 'l1_ratio': 0.25}
# mean: -1674.03696, std: 75.42201, params: {'alpha': 0.01, 'l1_ratio': 0.30000000000000004}
# mean: -1675.05972, std: 74.69801, params: {'alpha': 0.01, 'l1_ratio': 0.35000000000000003}
# mean: -1674.02733, std: 74.79108, params: {'alpha': 0.01, 'l1_ratio': 0.40000000000000002}
# mean: -1673.66340, std: 75.24172, params: {'alpha': 0.01, 'l1_ratio': 0.45000000000000001}
# mean: -1674.26057, std: 74.75838, params: {'alpha': 0.01, 'l1_ratio': 0.5}
# mean: -1674.11115, std: 76.20714, params: {'alpha': 0.01, 'l1_ratio': 0.55000000000000004}
# mean: -1675.09090, std: 74.72449, params: {'alpha': 0.01, 'l1_ratio': 0.60000000000000009}
# mean: -1674.36100, std: 76.00914, params: {'alpha': 0.01, 'l1_ratio': 0.65000000000000002}
# mean: -1674.07247, std: 75.63877, params: {'alpha': 0.01, 'l1_ratio': 0.70000000000000007}
# mean: -1674.74821, std: 75.85369, params: {'alpha': 0.01, 'l1_ratio': 0.75}
# mean: -1674.17683, std: 75.94487, params: {'alpha': 0.01, 'l1_ratio': 0.80000000000000004}
# mean: -1673.80717, std: 75.47380, params: {'alpha': 0.01, 'l1_ratio': 0.85000000000000009}
# mean: -1674.71454, std: 75.87518, params: {'alpha': 0.01, 'l1_ratio': 0.90000000000000002}
# mean: -1673.79935, std: 76.00421, params: {'alpha': 0.01, 'l1_ratio': 0.95000000000000007}
# mean: -1675.08212, std: 76.07666, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.0}
# mean: -1675.78096, std: 74.99356, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.050000000000000003}
# mean: -1675.67821, std: 77.22305, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.10000000000000001}
# mean: -1675.11449, std: 75.43408, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.15000000000000002}
# mean: -1675.63244, std: 74.16661, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.20000000000000001}
# mean: -1675.28288, std: 74.68220, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.25}
# mean: -1675.01660, std: 75.45599, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.30000000000000004}
# mean: -1675.07072, std: 75.82340, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.35000000000000003}
# mean: -1674.60961, std: 75.53319, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.40000000000000002}
# mean: -1675.56026, std: 73.44046, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.45000000000000001}
# mean: -1674.82544, std: 74.97934, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.5}
# mean: -1675.42137, std: 75.11006, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.55000000000000004}
# mean: -1676.73814, std: 73.10246, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.60000000000000009}
# mean: -1675.39720, std: 75.78265, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.65000000000000002}
# mean: -1675.36577, std: 75.16171, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.70000000000000007}
# mean: -1675.31698, std: 75.75067, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.75}
# mean: -1675.09054, std: 76.07077, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.80000000000000004}
# mean: -1675.54898, std: 75.01000, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.85000000000000009}
# mean: -1675.12908, std: 74.54880, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.90000000000000002}
# mean: -1675.71882, std: 74.58172, params: {'alpha': 0.10000000000000001, 'l1_ratio': 0.95000000000000007}

# %% [markdown]
# Conclusion: From what is discussed in class, people usually use Ridge (L2) when there are more observations than features, just like our modeldata, which consists of 17378 observations and 5 features only. However, from the above experiments, I find that there are not that much difference between using Lasso or Ridge. MSE is minimized in roughly the same pace as n_iter increases (here I show n_iter = 5 and 50). L1_ratio does not affect the result for each alpha I use. However, for larger alphas (e.g. 1e-1), Lasso performs better than Ridge.

# %%
eta0s = np.logspace(-10, 2, 13)
params = {'eta0' : eta0s}

gs = grid_search.GridSearchCV(
    estimator=linear_model.SGDRegressor(n_iter=50),
    cv=cross_validation.KFold(len(modeldata), n_folds=5, shuffle=True),
    param_grid=params,
    scoring='neg_mean_squared_error',
    )

gs.fit(modeldata, y)

print 'BEST ESTIMATOR'
print -gs.best_score_
print gs.best_estimator_
print 'ALL ESTIMATORS'
for l2 in gs.grid_scores_:
    print l2
# Out:
# BEST ESTIMATOR
# 1673.70850743
# SGDRegressor(alpha=0.0001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', n_iter=50, penalty='l2', power_t=0.25,
#        random_state=None, shuffle=True, verbose=0, warm_start=False)
# ALL ESTIMATORS
# mean: -3703.62012, std: 98.66110, params: {'eta0': 1e-10}
# mean: -3703.45285, std: 98.65998, params: {'eta0': 1.0000000000000001e-09}
# mean: -3701.78131, std: 98.64855, params: {'eta0': 1e-08}
# mean: -3685.18065, std: 98.54057, params: {'eta0': 9.9999999999999995e-08}
# mean: -3530.04602, std: 97.45148, params: {'eta0': 9.9999999999999995e-07}
# mean: -2692.86906, std: 88.59556, params: {'eta0': 1.0000000000000001e-05}
# mean: -2225.53173, std: 75.71625, params: {'eta0': 0.0001}
# mean: -1748.67156, std: 70.89127, params: {'eta0': 0.001}
# mean: -1673.70851, std: 67.48736, params: {'eta0': 0.01}
# mean: -1680.49660, std: 66.04562, params: {'eta0': 0.10000000000000001}
# mean: -1683.01051, std: 62.98784, params: {'eta0': 1.0}
# mean: -2762.01185, std: 704.39456, params: {'eta0': 10.0}
# mean: -21923400140243221704867840.00000, std: 18020496979040616778301440.00000, params: {'eta0': 100.0}

# %%
# Testing on eta0

eta0s = np.logspace(-3, 0, 13)
params = {'eta0' : eta0s}

gs = grid_search.GridSearchCV(
    estimator=linear_model.SGDRegressor(n_iter=50),
    cv=cross_validation.KFold(len(modeldata), n_folds=5, shuffle=True),
    param_grid=params,
    scoring='neg_mean_squared_error',
    )

gs.fit(modeldata, y)

print 'BEST ESTIMATOR'
print -gs.best_score_
print gs.best_estimator_
print 'ALL ESTIMATORS'
for l2 in gs.grid_scores_:
    print l2
# Out:
# BEST ESTIMATOR
# 1674.32071031
# SGDRegressor(alpha=0.0001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', n_iter=50, penalty='l2', power_t=0.25,
#        random_state=None, shuffle=True, verbose=0, warm_start=False)
# ALL ESTIMATORS
# mean: -1749.27782, std: 129.18276, params: {'eta0': 0.001}
# mean: -1689.17670, std: 122.64226, params: {'eta0': 0.0017782794100389228}
# mean: -1675.56223, std: 118.82469, params: {'eta0': 0.0031622776601683794}
# mean: -1674.65705, std: 117.34678, params: {'eta0': 0.005623413251903491}
# mean: -1674.32071, std: 117.74774, params: {'eta0': 0.01}
# mean: -1676.17259, std: 115.12102, params: {'eta0': 0.017782794100389229}
# mean: -1676.27391, std: 120.21613, params: {'eta0': 0.031622776601683791}
# mean: -1684.69838, std: 105.97641, params: {'eta0': 0.056234132519034911}
# mean: -1683.17525, std: 109.31637, params: {'eta0': 0.10000000000000001}
# mean: -1678.58726, std: 121.12560, params: {'eta0': 0.17782794100389229}
# mean: -1722.25417, std: 146.58645, params: {'eta0': 0.31622776601683794}
# mean: -1715.32918, std: 135.78526, params: {'eta0': 0.56234132519034907}
# mean: -1702.84178, std: 124.15731, params: {'eta0': 1.0}

# %% [markdown]
# The learning rate, eta0, should be around 0.01 (0.003 ~ 0.03 are all acceptable values)

# %%
# Repeating the same using L1

eta0s = np.logspace(-3, 0, 13)
params = {'eta0' : eta0s}

gs = grid_search.GridSearchCV(
    estimator=linear_model.SGDRegressor(n_iter=50, penalty='l1'),
    cv=cross_validation.KFold(len(modeldata), n_folds=5, shuffle=True),
    param_grid=params,
    scoring='neg_mean_squared_error',
    )

gs.fit(modeldata, y)

print 'BEST ESTIMATOR'
print -gs.best_score_
print gs.best_estimator_
print 'ALL ESTIMATORS'
for l1 in gs.grid_scores_:
    print l1
# Out:
# BEST ESTIMATOR
# 1673.97798121
# SGDRegressor(alpha=0.0001, average=False, epsilon=0.1,
#        eta0=0.005623413251903491, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='invscaling', loss='squared_loss', n_iter=50,
#        penalty='l1', power_t=0.25, random_state=None, shuffle=True,
#        verbose=0, warm_start=False)
# ALL ESTIMATORS
# mean: -1748.42228, std: 92.46752, params: {'eta0': 0.001}
# mean: -1688.13414, std: 91.27439, params: {'eta0': 0.0017782794100389228}
# mean: -1674.63451, std: 90.91249, params: {'eta0': 0.0031622776601683794}
# mean: -1673.97798, std: 91.08631, params: {'eta0': 0.005623413251903491}
# mean: -1674.19443, std: 90.45945, params: {'eta0': 0.01}
# mean: -1674.70289, std: 92.13233, params: {'eta0': 0.017782794100389229}
# mean: -1674.88824, std: 89.65987, params: {'eta0': 0.031622776601683791}
# mean: -1676.97523, std: 86.04203, params: {'eta0': 0.056234132519034911}
# mean: -1675.22011, std: 91.34700, params: {'eta0': 0.10000000000000001}
# mean: -1686.67799, std: 96.79900, params: {'eta0': 0.17782794100389229}
# mean: -1687.05543, std: 89.77881, params: {'eta0': 0.31622776601683794}
# mean: -1702.36145, std: 104.75282, params: {'eta0': 0.56234132519034907}
# mean: -1704.36301, std: 97.61813, params: {'eta0': 1.0}

# %% [markdown]
# Results are very similar to that using L2.

# %% [markdown]
# Conclusion: The stochastic gradient descent approach (SGD) seems to be outperform Ridge as we can minimize MSE in each iteration. MSE falls to a local minimum around 1673 after about 5-10 iterations. Previously, Ridge produces MSE of about 1814. Using the SGD also allows me to test different approach (L2, L1, Elastic Net). Gradient descent can take a lot of time and computationally expensive when the data is huge and we do not know exactly how large it is and thus set a large number of iternations to ensure a good result.
